# %%
import matplotlib.pyplot as plt
from PIL import Image
import cv2
import numpy as np
import os
from ultralytics import YOLO
import chess
from stockfish import Stockfish
import time
import threading

# %%
model_path = os.path.join('.', 'runs', 'segment', 'train_CB', 'weights', 'best.pt')
model = YOLO(model_path)

model_path1 = os.path.join('.', 'runs', 'detect', 'train_GCP', 'weights', 'best.pt')
model1 = YOLO(model_path1)

video = cv2.VideoCapture(0)
address = "https://192.168.1.5:8080/video" #ADD CUSTOM ADDRESS HERE!
video.open(address)

if not video.isOpened():
    print("Error: Could not open video stream.")
    exit()

stockfish=Stockfish("StockFish/stockfish-windows-x86-64-avx2.exe")

top_moves = []

while True:
    ret, frame = video.read()
    if not ret:
        print("Error: Failed to capture frame.")
        break

    results = model.predict(frame, conf=0.5)

    warping_done = False

    for result in results:
        
        if hasattr(result, 'masks') and result.masks is not None:
            masks = result.masks.data.cpu().numpy()  

            for i in range(masks.shape[0]):
                
                mask = masks[i]
                mask_binary = (mask * 255).astype(np.uint8)
                mask_binary_resized = cv2.resize(mask_binary, (frame.shape[1], frame.shape[0]), interpolation=cv2.INTER_NEAREST)
                masked_frame = cv2.bitwise_and(frame, frame, mask=mask_binary_resized)
                contours, _ = cv2.findContours(mask_binary_resized, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
                
                if contours:
                    
                    largest_contour = max(contours, key=cv2.contourArea)
                    epsilon = 0.02 * cv2.arcLength(largest_contour, True)
                    approx_corners = cv2.approxPolyDP(largest_contour, epsilon, True)

                    if len(approx_corners) == 4:
                        
                        src_pts = np.array([pt[0] for pt in approx_corners], dtype="float32")
                        dst_pts = np.array([[0, 0], [600, 0], [600, 600], [0, 600]], dtype="float32")
                        
                        M = cv2.getPerspectiveTransform(src_pts, dst_pts)
                        warped_frame = cv2.warpPerspective(masked_frame, M, (600, 600))
                        rotated_frame = cv2.rotate(warped_frame, cv2.ROTATE_90_CLOCKWISE)
                        mirrored_frame = cv2.flip(rotated_frame, 1)

                        grid_size = 600
                        rows, cols = 8, 8
                        cell_width = grid_size // cols
                        cell_height = grid_size // rows

                        img_with_grid = mirrored_frame.copy()
                        for r in range(1, rows):
                            y = r * cell_height
                            cv2.line(img_with_grid, (0, y), (grid_size, y), (255, 0, 0), 1)
                        for c in range(1, cols):
                            x = c * cell_width
                            cv2.line(img_with_grid, (x, 0), (x, grid_size), (255, 0, 0), 1)

                        warping_done = True
                    else:
                        print("Could not find 4 corners for perspective transformation.")
                else:
                    print("No contours found for the mask.")
        else:
            print("No masks found in the results.")
    
    if not warping_done:
        for result in results:
            if hasattr(result, 'boxes') and result.boxes is not None:
                boxes = result.boxes.xyxy.cpu().numpy() 
                
                if len(boxes) > 0:
                    print("in")
                    x_min, y_min, x_max, y_max = boxes[0]
                    src_pts = np.array([[x_min, y_min], [x_max, y_min], [x_max, y_max], [x_min, y_max]], dtype="float32")
                    dst_pts = np.array([[0, 0], [600, 0], [600, 600], [0, 600]], dtype="float32")

                    M = cv2.getPerspectiveTransform(src_pts, dst_pts)
                    warped_frame = cv2.warpPerspective(frame, M, (600, 600))
                    rotated_frame = cv2.rotate(warped_frame, cv2.ROTATE_90_CLOCKWISE)
                    mirrored_frame = cv2.flip(rotated_frame, 1)

                    grid_size = 600
                    rows, cols = 8, 8
                    cell_width = grid_size // cols
                    cell_height = grid_size // rows
                    
                    img_with_grid = mirrored_frame.copy()
                    print(img_with_grid)
                    for r in range(1, rows):
                        y = r * cell_height
                        cv2.line(img_with_grid, (0, y), (grid_size, y), (255, 0, 0), 1)
                    for c in range(1, cols):
                        x = c * cell_width
                        cv2.line(img_with_grid, (x, 0), (x, grid_size), (255, 0, 0), 1)
                        
                    warping_done = True
                    break

    if not warping_done:
        frameResized = cv2.resize(frame, (600, 600))
        cv2.imshow("Chessboard", frameResized)
            
    else:
        columns = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h']
        rows_labels = ['1', '2', '3', '4', '5', '6', '7', '8']
        rows_labels.reverse()
    
        img_with_labels = img_with_grid.copy()
    
        for i in range(rows):
            for j in range(cols):
                x = i * cell_width
                y = j * cell_height
        
                label = columns[i] + rows_labels[j]
    
                text_x = x + cell_width // 2 - 15 
                text_y = y + cell_height // 2 + 15
        
                cv2.putText(img_with_labels, label, (text_x, text_y), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 0, 255), 2)
    
        res = img_with_labels.copy()
    
        piece_positions = {}
        
        results1 = model1.predict(mirrored_frame, conf=0.7)
        
        for result in results1:
            
            boxes = result.boxes.xyxy.cpu().numpy()
            classes = result.boxes.cls.cpu().numpy()
            names = result.names
            
            for box,class_id in zip(boxes,classes):
                
                x_min,y_min,x_max,y_max = box
                center_x = (x_min + x_max) / 2
                center_y = ((y_min + y_max) / 2)
                
                grid_col = int(center_x // cell_width)
                grid_row = int(center_y // cell_height)
                
                if 0 <= grid_col < cols and 0 <= grid_row < rows:
                    
                    grid_label = columns[grid_col] + rows_labels[grid_row]
                    piece_positions[grid_label] = names[int(class_id)]
                    
                    cv2.circle(res, (int(center_x), int(center_y)), 5, (255, 0, 0), -1)
                    cv2.putText(res, grid_label, (int(center_x)-10, int(center_y)-15), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 0, 255), 2)
    
        piece_map = {
            'white-rook': chess.Piece(chess.ROOK, chess.WHITE),
            'white-knight': chess.Piece(chess.KNIGHT, chess.WHITE),
            'white-bishop': chess.Piece(chess.BISHOP, chess.WHITE),
            'white-queen': chess.Piece(chess.QUEEN, chess.WHITE),
            'white-king': chess.Piece(chess.KING, chess.WHITE),
            'white-pawn': chess.Piece(chess.PAWN, chess.WHITE),
            'black-rook': chess.Piece(chess.ROOK, chess.BLACK),
            'black-knight': chess.Piece(chess.KNIGHT, chess.BLACK),
            'black-bishop': chess.Piece(chess.BISHOP, chess.BLACK),
            'black-queen': chess.Piece(chess.QUEEN, chess.BLACK),
            'black-king': chess.Piece(chess.KING, chess.BLACK),
            'black-pawn': chess.Piece(chess.PAWN, chess.BLACK),
        }
        
        def set_up_board(board, piece_positions, top_moves):
    
            try:
                for position, piece_description in piece_positions.items():
                    piece = piece_map.get(piece_description)
                    if piece:
                        square = chess.parse_square(position)
                        board.set_piece_at(square, piece)
                    else:
                        raise ValueError(f"Invalid piece description: {piece_description}")
            except Exception as e:
                print(f"Error setting up board: {e}")
                return top_moves
        
            fen_string = board.fen()

            try:
                new_board = chess.Board(fen_string)
                if not new_board.is_valid():
                    raise ValueError("Generated FEN is invalid.")
            except ValueError as e:
                print(f"Error: {e}")
                return top_moves 

            board = new_board
            
            try:
                stockfish.set_fen_position(board.fen())
                top_moves = stockfish.get_top_moves(1)
            except Exception as e:
                print(f"Stockfish error: {e}")
            
            return top_moves
            
        board = chess.Board(None)
        board.turn = chess.WHITE
        top_moves = set_up_board(board, piece_positions, top_moves)
        
        img_with_Ans = img_with_grid.copy()
        for move in top_moves:
            start_label = move['Move'][:2]  
            end_label = move['Move'][2:]
            
            for i in range(rows):
                for j in range(cols):
                    x = i * cell_width
                    y = j * cell_height
                    label = columns[i] + rows_labels[j]
                    
                    text_x = x + cell_width // 2
                    text_y = y + cell_height // 2
                    
                    if label == start_label:
                        start_x = text_x
                        start_y = text_y
                        cv2.circle(img_with_Ans, (int(text_x), int(text_y)), 5, (0, 0, 255), -1)
                        cv2.putText(img_with_Ans, label, (text_x, text_y), cv2.FONT_HERSHEY_SIMPLEX, 1, (100, 0, 255), 2)
                    
                    if label == end_label:
                        end_x = text_x
                        end_y = text_y
                        cv2.circle(img_with_Ans, (int(text_x), int(text_y)), 5, (0, 0, 255), -1)
                        cv2.putText(img_with_Ans, label, (text_x, text_y), cv2.FONT_HERSHEY_SIMPLEX, 1, (100, 0, 255), 2)
            
            cv2.arrowedLine(img_with_Ans, (start_x, start_y), (end_x, end_y), (255, 0, 0), 1, tipLength=0.1)
        
        
        cv2.imshow("Chessboard", img_with_Ans)
    
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

video.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x800 (no detections), 142.9ms
# Speed: 4.0ms preprocess, 142.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 (no detections), 134.6ms
# Speed: 4.0ms preprocess, 134.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 (no detections), 132.9ms
# Speed: 3.0ms preprocess, 132.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 (no detections), 139.0ms
# Speed: 3.1ms preprocess, 139.0ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 (no detections), 129.9ms
# Speed: 3.1ms preprocess, 129.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 (no detections), 127.5ms
# Speed: 2.0ms preprocess, 127.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 (no detections), 134.4ms
# Speed: 3.0ms preprocess, 134.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 (no detections), 140.0ms
# Speed: 3.0ms preprocess, 140.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 (no detections), 126.6ms
# Speed: 3.0ms preprocess, 126.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 (no detections), 157.6ms
# Speed: 3.0ms preprocess, 157.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 (no detections), 137.7ms
# Speed: 4.0ms preprocess, 137.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 (no detections), 140.4ms
# Speed: 3.0ms preprocess, 140.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 (no detections), 157.4ms
# Speed: 4.0ms preprocess, 157.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 (no detections), 116.3ms
# Speed: 2.0ms preprocess, 116.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 (no detections), 112.5ms
# Speed: 2.9ms preprocess, 112.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 (no detections), 99.1ms
# Speed: 3.0ms preprocess, 99.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 (no detections), 114.6ms
# Speed: 3.0ms preprocess, 114.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 (no detections), 91.3ms
# Speed: 3.0ms preprocess, 91.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 (no detections), 97.1ms
# Speed: 3.0ms preprocess, 97.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 (no detections), 80.7ms
# Speed: 3.0ms preprocess, 80.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 (no detections), 76.7ms
# Speed: 2.0ms preprocess, 76.7ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 (no detections), 78.2ms
# Speed: 2.0ms preprocess, 78.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 (no detections), 81.9ms
# Speed: 2.0ms preprocess, 81.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 (no detections), 74.6ms
# Speed: 2.0ms preprocess, 74.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 (no detections), 73.9ms
# Speed: 2.0ms preprocess, 73.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 (no detections), 75.5ms
# Speed: 2.1ms preprocess, 75.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 (no detections), 85.3ms
# Speed: 2.0ms preprocess, 85.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 (no detections), 75.7ms
# Speed: 2.0ms preprocess, 75.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 (no detections), 199.4ms
# Speed: 2.0ms preprocess, 199.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 (no detections), 187.9ms
# Speed: 6.0ms preprocess, 187.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 (no detections), 194.0ms
# Speed: 4.9ms preprocess, 194.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 (no detections), 189.9ms
# Speed: 3.9ms preprocess, 189.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 (no detections), 196.0ms
# Speed: 4.0ms preprocess, 196.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 (no detections), 198.6ms
# Speed: 5.0ms preprocess, 198.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 1 0, 204.0ms
# Speed: 7.1ms preprocess, 204.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 (no detections), 154.7ms
# Speed: 5.5ms preprocess, 154.7ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 93.2ms
# Speed: 3.0ms preprocess, 93.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 4 white-pawns, 1 white-queen, 101.2ms
# Speed: 4.1ms preprocess, 101.2ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 102.3ms
# Speed: 2.1ms preprocess, 102.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 4 white-pawns, 1 white-queen, 100.3ms
# Speed: 3.0ms preprocess, 100.3ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 87.8ms
# Speed: 2.0ms preprocess, 87.8ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 3 white-pawns, 1 white-queen, 120.3ms
# Speed: 2.9ms preprocess, 120.3ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 77.9ms
# Speed: 2.0ms preprocess, 77.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 3 black-bishops, 4 black-pawns, 1 black-queen, 3 white-pawns, 1 white-queen, 87.7ms
# Speed: 3.0ms preprocess, 87.7ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 74.3ms
# Speed: 3.0ms preprocess, 74.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 3 black-bishops, 4 black-pawns, 1 black-queen, 4 white-pawns, 1 white-queen, 90.5ms
# Speed: 4.1ms preprocess, 90.5ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 73.8ms
# Speed: 1.9ms preprocess, 73.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 2 black-bishops, 1 black-knight, 4 black-pawns, 1 black-queen, 1 white-king, 4 white-pawns, 1 white-queen, 83.5ms
# Speed: 3.0ms preprocess, 83.5ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 74.8ms
# Speed: 2.0ms preprocess, 74.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 2 black-bishops, 1 black-knight, 4 black-pawns, 1 black-queen, 4 white-pawns, 1 white-queen, 86.0ms
# Speed: 3.0ms preprocess, 86.0ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 74.7ms
# Speed: 2.0ms preprocess, 74.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 3 white-pawns, 1 white-queen, 81.1ms
# Speed: 3.1ms preprocess, 81.1ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 75.7ms
# Speed: 2.9ms preprocess, 75.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 4 black-pawns, 1 black-queen, 1 black-rook, 3 white-pawns, 1 white-queen, 86.9ms
# Speed: 3.0ms preprocess, 86.9ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 78.7ms
# Speed: 3.0ms preprocess, 78.7ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 3 white-pawns, 1 white-queen, 91.7ms
# Speed: 3.0ms preprocess, 91.7ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 77.0ms
# Speed: 2.9ms preprocess, 77.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 4 white-pawns, 1 white-queen, 85.6ms
# Speed: 2.0ms preprocess, 85.6ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 81.1ms
# Speed: 2.0ms preprocess, 81.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 5 black-pawns, 1 black-queen, 1 black-rook, 3 white-pawns, 1 white-queen, 91.1ms
# Speed: 3.0ms preprocess, 91.1ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 75.8ms
# Speed: 2.0ms preprocess, 75.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 3 black-bishops, 1 black-king, 4 black-pawns, 1 black-queen, 1 black-rook, 4 white-pawns, 1 white-queen, 84.7ms
# Speed: 2.9ms preprocess, 84.7ms inference, 1.1ms postprocess per image at shape (1, 3, 800, 800)
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 72.8ms
# Speed: 2.0ms preprocess, 72.8ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 3 black-bishops, 1 black-king, 4 black-pawns, 1 black-queen, 1 black-rook, 3 white-pawns, 1 white-queen, 84.0ms
# Speed: 2.9ms preprocess, 84.0ms inference, 1.6ms postprocess per image at shape (1, 3, 800, 800)
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 76.1ms
# Speed: 2.0ms preprocess, 76.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 4 black-pawns, 1 black-rook, 1 white-bishop, 2 white-pawns, 1 white-queen, 104.9ms
# Speed: 3.1ms preprocess, 104.9ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 81.0ms
# Speed: 2.0ms preprocess, 81.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 3 black-bishops, 1 black-king, 4 black-pawns, 1 black-rook, 3 white-pawns, 1 white-queen, 87.7ms
# Speed: 2.9ms preprocess, 87.7ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 80.1ms
# Speed: 2.0ms preprocess, 80.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 4 black-pawns, 1 black-rook, 1 white-bishop, 3 white-pawns, 1 white-queen, 88.5ms
# Speed: 3.9ms preprocess, 88.5ms inference, 1.1ms postprocess per image at shape (1, 3, 800, 800)
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 77.9ms
# Speed: 3.0ms preprocess, 77.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 4 black-pawns, 1 black-rook, 1 white-bishop, 2 white-pawns, 1 white-queen, 86.0ms
# Speed: 2.9ms preprocess, 86.0ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 74.3ms
# Speed: 2.9ms preprocess, 74.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 4 black-pawns, 1 black-rook, 1 white-bishop, 2 white-pawns, 1 white-queen, 83.3ms
# Speed: 3.0ms preprocess, 83.3ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 73.0ms
# Speed: 2.0ms preprocess, 73.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 4 black-pawns, 1 black-rook, 1 white-bishop, 3 white-pawns, 1 white-queen, 99.4ms
# Speed: 3.0ms preprocess, 99.4ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 81.2ms
# Speed: 2.0ms preprocess, 81.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 4 black-pawns, 1 black-rook, 1 white-bishop, 3 white-pawns, 1 white-queen, 90.8ms
# Speed: 3.0ms preprocess, 90.8ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 74.6ms
# Speed: 3.0ms preprocess, 74.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 5 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 2 white-pawns, 1 white-queen, 86.3ms
# Speed: 2.9ms preprocess, 86.3ms inference, 0.9ms postprocess per image at shape (1, 3, 800, 800)
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 79.0ms
# Speed: 2.0ms preprocess, 79.0ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 5 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 3 white-pawns, 1 white-queen, 82.0ms
# Speed: 3.0ms preprocess, 82.0ms inference, 1.1ms postprocess per image at shape (1, 3, 800, 800)
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 74.0ms
# Speed: 2.1ms preprocess, 74.0ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 3 white-pawns, 1 white-queen, 89.1ms
# Speed: 3.0ms preprocess, 89.1ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 88.0ms
# Speed: 3.0ms preprocess, 88.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 6 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-pawn, 1 white-queen, 96.9ms
# Speed: 3.1ms preprocess, 96.9ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 80.0ms
# Speed: 2.0ms preprocess, 80.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 5 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 3 white-pawns, 1 white-queen, 89.0ms
# Speed: 3.0ms preprocess, 89.0ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 78.0ms
# Speed: 2.0ms preprocess, 78.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 1 black-knight, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 3 white-pawns, 1 white-queen, 89.0ms
# Speed: 3.1ms preprocess, 89.0ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 0, 78.2ms
# Speed: 2.1ms preprocess, 78.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 1 black-knight, 5 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 3 white-pawns, 1 white-queen, 92.6ms
# Speed: 3.0ms preprocess, 92.6ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 0, 86.1ms
# Speed: 2.0ms preprocess, 86.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 1 black-knight, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 3 white-pawns, 1 white-queen, 91.1ms
# Speed: 2.9ms preprocess, 91.1ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 0, 89.7ms
# Speed: 2.0ms preprocess, 89.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 1 black-knight, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 3 white-pawns, 1 white-queen, 91.0ms
# Speed: 4.0ms preprocess, 91.0ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 0, 80.0ms
# Speed: 2.9ms preprocess, 80.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 1 black-knight, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 3 white-pawns, 1 white-queen, 91.0ms
# Speed: 3.0ms preprocess, 91.0ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 0, 80.0ms
# Speed: 3.0ms preprocess, 80.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 1 black-knight, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 4 white-pawns, 1 white-queen, 108.5ms
# Speed: 3.0ms preprocess, 108.5ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 0, 80.0ms
# Speed: 2.0ms preprocess, 80.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 1 black-knight, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 4 white-pawns, 1 white-queen, 92.1ms
# Speed: 2.9ms preprocess, 92.1ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 0, 80.0ms
# Speed: 3.0ms preprocess, 80.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 1 black-knight, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 3 white-pawns, 1 white-queen, 99.0ms
# Speed: 3.0ms preprocess, 99.0ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 0, 79.1ms
# Speed: 2.1ms preprocess, 79.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 1 black-knight, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 3 white-pawns, 1 white-queen, 90.0ms
# Speed: 3.0ms preprocess, 90.0ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 0, 87.5ms
# Speed: 3.0ms preprocess, 87.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 1 black-knight, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 4 white-pawns, 1 white-queen, 97.0ms
# Speed: 3.0ms preprocess, 97.0ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 0, 80.1ms
# Speed: 2.0ms preprocess, 80.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 1 black-knight, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 4 white-pawns, 1 white-queen, 91.6ms
# Speed: 3.0ms preprocess, 91.6ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 0, 81.0ms
# Speed: 2.0ms preprocess, 81.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 1 black-knight, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 4 white-pawns, 1 white-queen, 90.7ms
# Speed: 3.0ms preprocess, 90.7ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 0, 85.9ms
# Speed: 2.0ms preprocess, 85.9ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 1 black-knight, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 4 white-pawns, 1 white-queen, 97.1ms
# Speed: 4.9ms preprocess, 97.1ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 0, 79.0ms
# Speed: 2.9ms preprocess, 79.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 1 black-knight, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-king, 4 white-pawns, 1 white-queen, 88.1ms
# Speed: 3.0ms preprocess, 88.1ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 0, 76.3ms
# Speed: 2.0ms preprocess, 76.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 1 black-knight, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 4 white-pawns, 1 white-queen, 93.1ms
# Speed: 2.9ms preprocess, 93.1ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 0, 84.0ms
# Speed: 1.9ms preprocess, 84.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 1 black-knight, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 4 white-pawns, 1 white-queen, 107.5ms
# Speed: 3.0ms preprocess, 107.5ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 0, 79.3ms
# Speed: 2.1ms preprocess, 79.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 1 black-knight, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 4 white-pawns, 1 white-queen, 101.9ms
# Speed: 3.1ms preprocess, 101.9ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 0, 85.0ms
# Speed: 2.1ms preprocess, 85.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 1 black-knight, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-king, 4 white-pawns, 1 white-queen, 94.0ms
# Speed: 3.0ms preprocess, 94.0ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 0, 79.0ms
# Speed: 2.0ms preprocess, 79.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 1 black-knight, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 4 white-pawns, 1 white-queen, 100.0ms
# Speed: 3.0ms preprocess, 100.0ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 0, 76.0ms
# Speed: 1.0ms preprocess, 76.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 1 black-knight, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 4 white-pawns, 1 white-queen, 90.0ms
# Speed: 3.1ms preprocess, 90.0ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 0, 77.1ms
# Speed: 2.0ms preprocess, 77.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 1 black-knight, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 4 white-pawns, 1 white-queen, 88.0ms
# Speed: 3.0ms preprocess, 88.0ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 0, 86.1ms
# Speed: 2.0ms preprocess, 86.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 1 black-knight, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 4 white-pawns, 1 white-queen, 94.0ms
# Speed: 2.0ms preprocess, 94.0ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 0, 80.1ms
# Speed: 2.0ms preprocess, 80.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 1 black-knight, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 4 white-pawns, 1 white-queen, 91.1ms
# Speed: 3.9ms preprocess, 91.1ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 0, 76.2ms
# Speed: 2.0ms preprocess, 76.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 1 black-knight, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 4 white-pawns, 1 white-queen, 99.7ms
# Speed: 3.0ms preprocess, 99.7ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 0, 91.6ms
# Speed: 2.1ms preprocess, 91.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 1 black-knight, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 4 white-pawns, 1 white-queen, 99.9ms
# Speed: 3.0ms preprocess, 99.9ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 0, 95.0ms
# Speed: 3.0ms preprocess, 95.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 1 black-knight, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 4 white-pawns, 1 white-queen, 110.8ms
# Speed: 3.0ms preprocess, 110.8ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 0, 98.4ms
# Speed: 2.0ms preprocess, 98.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 1 black-knight, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 4 white-pawns, 1 white-queen, 93.0ms
# Speed: 3.0ms preprocess, 93.0ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 0, 92.0ms
# Speed: 3.0ms preprocess, 92.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 3 black-bishops, 1 black-king, 1 black-knight, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-king, 4 white-pawns, 1 white-queen, 103.0ms
# Speed: 3.0ms preprocess, 103.0ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 0, 88.0ms
# Speed: 3.0ms preprocess, 88.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 3 black-bishops, 1 black-king, 1 black-knight, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-king, 4 white-pawns, 1 white-queen, 100.9ms
# Speed: 3.1ms preprocess, 100.9ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 0, 79.9ms
# Speed: 2.9ms preprocess, 79.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 3 black-bishops, 1 black-king, 1 black-knight, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-king, 4 white-pawns, 1 white-queen, 95.0ms
# Speed: 3.0ms preprocess, 95.0ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 0, 79.2ms
# Speed: 3.0ms preprocess, 79.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 1 black-knight, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 4 white-pawns, 1 white-queen, 90.0ms
# Speed: 3.0ms preprocess, 90.0ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 0, 87.4ms
# Speed: 3.0ms preprocess, 87.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 1 black-knight, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 4 white-pawns, 1 white-queen, 94.0ms
# Speed: 3.0ms preprocess, 94.0ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 0, 81.0ms
# Speed: 2.0ms preprocess, 81.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 1 black-knight, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 4 white-pawns, 1 white-queen, 90.1ms
# Speed: 3.0ms preprocess, 90.1ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 0, 90.1ms
# Speed: 1.9ms preprocess, 90.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 1 black-knight, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 4 white-pawns, 1 white-queen, 91.3ms
# Speed: 3.0ms preprocess, 91.3ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 0, 83.0ms
# Speed: 1.9ms preprocess, 83.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 1 black-knight, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 4 white-pawns, 1 white-queen, 99.0ms
# Speed: 2.1ms preprocess, 99.0ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 0, 81.1ms
# Speed: 1.0ms preprocess, 81.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 1 black-knight, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 4 white-pawns, 1 white-queen, 97.9ms
# Speed: 2.0ms preprocess, 97.9ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 0, 80.1ms
# Speed: 2.0ms preprocess, 80.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 1 black-knight, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 4 white-pawns, 1 white-queen, 137.9ms
# Speed: 3.0ms preprocess, 137.9ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 0, 133.0ms
# Speed: 3.0ms preprocess, 133.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 1 black-knight, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 4 white-pawns, 1 white-queen, 158.9ms
# Speed: 4.0ms preprocess, 158.9ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 0, 133.0ms
# Speed: 2.0ms preprocess, 133.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 1 black-knight, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 4 white-pawns, 1 white-queen, 143.1ms
# Speed: 3.0ms preprocess, 143.1ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 0, 135.8ms
# Speed: 2.1ms preprocess, 135.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 1 black-knight, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 4 white-pawns, 1 white-queen, 155.0ms
# Speed: 3.0ms preprocess, 155.0ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 0, 140.9ms
# Speed: 2.1ms preprocess, 140.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 1 black-knight, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 4 white-pawns, 1 white-queen, 147.0ms
# Speed: 4.0ms preprocess, 147.0ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 0, 135.2ms
# Speed: 3.0ms preprocess, 135.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 1 black-knight, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 4 white-pawns, 1 white-queen, 121.1ms
# Speed: 3.0ms preprocess, 121.1ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 0, 92.0ms
# Speed: 2.0ms preprocess, 92.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 1 black-knight, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 4 white-pawns, 1 white-queen, 96.9ms
# Speed: 3.0ms preprocess, 96.9ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 0, 83.0ms
# Speed: 2.0ms preprocess, 83.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 3 black-bishops, 1 black-king, 1 black-knight, 5 black-pawns, 1 black-queen, 1 black-rook, 1 white-king, 4 white-pawns, 1 white-queen, 95.9ms
# Speed: 3.0ms preprocess, 95.9ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 138.8ms
# Speed: 3.1ms preprocess, 138.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 1 black-knight, 5 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 4 white-pawns, 1 white-queen, 111.8ms
# Speed: 4.0ms preprocess, 111.8ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 97.3ms
# Speed: 2.0ms preprocess, 97.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 1 black-knight, 5 black-pawns, 1 black-queen, 1 black-rook, 1 white-king, 4 white-pawns, 1 white-queen, 115.0ms
# Speed: 3.0ms preprocess, 115.0ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 95.8ms
# Speed: 3.2ms preprocess, 95.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 1 black-knight, 5 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 4 white-pawns, 1 white-queen, 119.0ms
# Speed: 3.0ms preprocess, 119.0ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 95.1ms
# Speed: 2.0ms preprocess, 95.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 1 black-knight, 5 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 4 white-pawns, 1 white-queen, 116.0ms
# Speed: 3.0ms preprocess, 116.0ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 97.9ms
# Speed: 2.0ms preprocess, 97.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 1 black-knight, 6 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 4 white-pawns, 1 white-queen, 118.9ms
# Speed: 4.0ms preprocess, 118.9ms inference, 1.1ms postprocess per image at shape (1, 3, 800, 800)
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 102.3ms
# Speed: 2.0ms preprocess, 102.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 1 black-knight, 5 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 4 white-pawns, 1 white-queen, 102.1ms
# Speed: 3.0ms preprocess, 102.1ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 94.9ms
# Speed: 2.0ms preprocess, 94.9ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 1 black-knight, 5 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 4 white-pawns, 1 white-queen, 106.7ms
# Speed: 3.1ms preprocess, 106.7ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 97.5ms
# Speed: 2.0ms preprocess, 97.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 1 black-knight, 5 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 3 white-pawns, 1 white-queen, 111.0ms
# Speed: 2.0ms preprocess, 111.0ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 104.1ms
# Speed: 3.0ms preprocess, 104.1ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 1 black-knight, 5 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 4 white-pawns, 1 white-queen, 108.3ms
# Speed: 3.0ms preprocess, 108.3ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 97.9ms
# Speed: 2.0ms preprocess, 97.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 1 black-knight, 5 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 4 white-pawns, 1 white-queen, 120.3ms
# Speed: 2.0ms preprocess, 120.3ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 100.2ms
# Speed: 3.5ms preprocess, 100.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 1 black-knight, 5 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 4 white-pawns, 1 white-queen, 99.3ms
# Speed: 2.9ms preprocess, 99.3ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 93.0ms
# Speed: 2.1ms preprocess, 93.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 1 black-knight, 5 black-pawns, 1 black-queen, 1 black-rook, 1 white-king, 4 white-pawns, 1 white-queen, 120.4ms
# Speed: 2.8ms preprocess, 120.4ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 100.8ms
# Speed: 2.0ms preprocess, 100.8ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 1 black-knight, 5 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 4 white-pawns, 1 white-queen, 109.0ms
# Speed: 3.0ms preprocess, 109.0ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 93.7ms
# Speed: 2.4ms preprocess, 93.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 1 black-knight, 5 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 4 white-pawns, 1 white-queen, 118.0ms
# Speed: 3.5ms preprocess, 118.0ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 97.9ms
# Speed: 2.0ms preprocess, 97.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 1 black-knight, 5 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 4 white-pawns, 1 white-queen, 100.9ms
# Speed: 3.2ms preprocess, 100.9ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 93.5ms
# Speed: 1.6ms preprocess, 93.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 1 black-knight, 5 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 3 white-pawns, 1 white-queen, 110.4ms
# Speed: 2.4ms preprocess, 110.4ms inference, 1.1ms postprocess per image at shape (1, 3, 800, 800)
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 85.6ms
# Speed: 2.0ms preprocess, 85.6ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 3 black-bishops, 1 black-king, 1 black-knight, 5 black-pawns, 1 black-queen, 1 black-rook, 1 white-king, 4 white-pawns, 1 white-queen, 98.0ms
# Speed: 3.0ms preprocess, 98.0ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 95.2ms
# Speed: 2.0ms preprocess, 95.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 1 black-knight, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 3 white-pawns, 1 white-queen, 98.3ms
# Speed: 3.0ms preprocess, 98.3ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 0, 87.7ms
# Speed: 2.1ms preprocess, 87.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 1 black-knight, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 4 white-pawns, 1 white-queen, 106.4ms
# Speed: 3.0ms preprocess, 106.4ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 0, 86.5ms
# Speed: 1.6ms preprocess, 86.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 1 black-knight, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 4 white-pawns, 1 white-queen, 100.0ms
# Speed: 2.6ms preprocess, 100.0ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 0, 93.2ms
# Speed: 1.7ms preprocess, 93.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 1 black-knight, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 4 white-pawns, 1 white-queen, 100.2ms
# Speed: 2.0ms preprocess, 100.2ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 0, 84.2ms
# Speed: 2.1ms preprocess, 84.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 1 black-knight, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 4 white-pawns, 1 white-queen, 104.1ms
# Speed: 4.3ms preprocess, 104.1ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 0, 113.9ms
# Speed: 2.1ms preprocess, 113.9ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 1 black-knight, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 4 white-pawns, 1 white-queen, 117.1ms
# Speed: 3.0ms preprocess, 117.1ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 0, 108.4ms
# Speed: 2.0ms preprocess, 108.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 1 black-knight, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 4 white-pawns, 1 white-queen, 106.8ms
# Speed: 3.1ms preprocess, 106.8ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 0, 84.1ms
# Speed: 1.6ms preprocess, 84.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 1 black-knight, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 4 white-pawns, 1 white-queen, 108.3ms
# Speed: 2.9ms preprocess, 108.3ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 0, 83.1ms
# Speed: 2.0ms preprocess, 83.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 1 black-knight, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 4 white-pawns, 1 white-queen, 96.9ms
# Speed: 4.1ms preprocess, 96.9ms inference, 1.6ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 0, 103.8ms
# Speed: 2.0ms preprocess, 103.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 1 black-knight, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 4 white-pawns, 1 white-queen, 106.7ms
# Speed: 3.8ms preprocess, 106.7ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 0, 113.4ms
# Speed: 2.7ms preprocess, 113.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 1 black-knight, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 3 white-pawns, 1 white-queen, 111.3ms
# Speed: 2.9ms preprocess, 111.3ms inference, 1.2ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 0, 94.6ms
# Speed: 2.1ms preprocess, 94.6ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 1 black-knight, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-king, 4 white-pawns, 1 white-queen, 188.6ms
# Speed: 3.0ms preprocess, 188.6ms inference, 2.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 0, 208.3ms
# Speed: 4.0ms preprocess, 208.3ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 1 black-knight, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 4 white-pawns, 1 white-queen, 213.7ms
# Speed: 6.0ms preprocess, 213.7ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 0, 194.8ms
# Speed: 2.9ms preprocess, 194.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 1 black-knight, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 4 white-pawns, 1 white-queen, 227.0ms
# Speed: 5.0ms preprocess, 227.0ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 0, 192.3ms
# Speed: 5.3ms preprocess, 192.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 1 black-knight, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 4 white-pawns, 1 white-queen, 214.1ms
# Speed: 5.9ms preprocess, 214.1ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 0, 210.2ms
# Speed: 4.0ms preprocess, 210.2ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 1 black-knight, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 4 white-pawns, 1 white-queen, 223.2ms
# Speed: 5.5ms preprocess, 223.2ms inference, 1.7ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 0, 199.3ms
# Speed: 4.0ms preprocess, 199.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 1 black-knight, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 4 white-pawns, 1 white-queen, 117.0ms
# Speed: 3.0ms preprocess, 117.0ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 0, 107.8ms
# Speed: 2.6ms preprocess, 107.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 1 black-knight, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 4 white-pawns, 1 white-queen, 110.7ms
# Speed: 2.9ms preprocess, 110.7ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 0, 107.9ms
# Speed: 2.6ms preprocess, 107.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 1 black-knight, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 4 white-pawns, 1 white-queen, 107.2ms
# Speed: 2.7ms preprocess, 107.2ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 0, 105.1ms
# Speed: 2.3ms preprocess, 105.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 1 black-knight, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 4 white-pawns, 1 white-queen, 115.1ms
# Speed: 3.2ms preprocess, 115.1ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 0, 95.7ms
# Speed: 2.0ms preprocess, 95.7ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 800)
#
# ...
# Speed: 3.0ms preprocess, 112.0ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 0, 94.7ms
# Speed: 2.0ms preprocess, 94.7ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-bishop, 1 black-king, 1 black-knight, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 4 white-pawns, 1 white-queen, 110.7ms
# Speed: 2.2ms preprocess, 110.7ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 0, 85.4ms
# Speed: 2.0ms preprocess, 85.4ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-bishop, 1 black-king, 1 black-knight, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 4 white-pawns, 1 white-queen, 110.2ms
# Speed: 3.0ms preprocess, 110.2ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 0, 89.8ms
# Speed: 2.2ms preprocess, 89.8ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-bishop, 1 black-king, 1 black-knight, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 4 white-pawns, 1 white-queen, 113.9ms
# Speed: 4.0ms preprocess, 113.9ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 0, 88.7ms
# Speed: 2.0ms preprocess, 88.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-bishop, 1 black-king, 1 black-knight, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 4 white-pawns, 1 white-queen, 119.1ms
# Speed: 3.0ms preprocess, 119.1ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 0, 100.1ms
# Speed: 2.0ms preprocess, 100.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-bishop, 1 black-king, 1 black-knight, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 4 white-pawns, 1 white-queen, 114.8ms
# Speed: 3.1ms preprocess, 114.8ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 0, 94.2ms
# Speed: 2.1ms preprocess, 94.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-bishop, 1 black-king, 1 black-knight, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 4 white-pawns, 1 white-queen, 116.1ms
# Speed: 2.6ms preprocess, 116.1ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 0, 93.5ms
# Speed: 2.3ms preprocess, 93.5ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-bishop, 1 black-king, 1 black-knight, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 4 white-pawns, 1 white-queen, 223.0ms
# Speed: 3.1ms preprocess, 223.0ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 0, 196.7ms
# Speed: 4.0ms preprocess, 196.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-bishop, 1 black-king, 1 black-knight, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 4 white-pawns, 1 white-queen, 218.7ms
# Speed: 6.1ms preprocess, 218.7ms inference, 1.3ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 0, 188.3ms
# Speed: 4.4ms preprocess, 188.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-bishop, 1 black-king, 1 black-knight, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 4 white-pawns, 1 white-queen, 214.1ms
# Speed: 6.0ms preprocess, 214.1ms inference, 1.5ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 0, 214.9ms
# Speed: 4.2ms preprocess, 214.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-bishop, 1 black-king, 1 black-knight, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 4 white-pawns, 1 white-queen, 211.6ms
# Speed: 6.0ms preprocess, 211.6ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 0, 118.0ms
# Speed: 3.2ms preprocess, 118.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-bishop, 1 black-king, 1 black-knight, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 4 white-pawns, 1 white-queen, 134.9ms
# Speed: 3.0ms preprocess, 134.9ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 0, 110.3ms
# Speed: 2.0ms preprocess, 110.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-bishop, 1 black-king, 1 black-knight, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 4 white-pawns, 1 white-queen, 114.1ms
# Speed: 2.7ms preprocess, 114.1ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 0, 95.1ms
# Speed: 3.1ms preprocess, 95.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-bishop, 1 black-king, 1 black-knight, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 4 white-pawns, 1 white-queen, 109.6ms
# Speed: 3.6ms preprocess, 109.6ms inference, 1.1ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 0, 90.0ms
# Speed: 2.1ms preprocess, 90.0ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-bishop, 1 black-king, 1 black-knight, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 4 white-pawns, 1 white-queen, 116.5ms
# Speed: 3.0ms preprocess, 116.5ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 0, 92.8ms
# Speed: 2.0ms preprocess, 92.8ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-bishop, 1 black-king, 1 black-knight, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 4 white-pawns, 1 white-queen, 112.7ms
# Speed: 3.1ms preprocess, 112.7ms inference, 1.6ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 0, 97.5ms
# Speed: 2.0ms preprocess, 97.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-bishop, 1 black-king, 1 black-knight, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 4 white-pawns, 1 white-queen, 116.9ms
# Speed: 3.0ms preprocess, 116.9ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 0, 95.1ms
# Speed: 2.0ms preprocess, 95.1ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-bishop, 1 black-king, 1 black-knight, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 4 white-pawns, 1 white-queen, 114.3ms
# Speed: 3.0ms preprocess, 114.3ms inference, 1.1ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 0, 97.7ms
# Speed: 2.1ms preprocess, 97.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-bishop, 1 black-king, 1 black-knight, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 4 white-pawns, 1 white-queen, 112.9ms
# Speed: 3.0ms preprocess, 112.9ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 0, 100.6ms
# Speed: 2.0ms preprocess, 100.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-bishop, 1 black-king, 1 black-knight, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 4 white-pawns, 1 white-queen, 115.3ms
# Speed: 2.6ms preprocess, 115.3ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 0, 105.1ms
# Speed: 2.0ms preprocess, 105.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-bishop, 1 black-king, 1 black-knight, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 4 white-pawns, 1 white-queen, 113.4ms
# Speed: 3.5ms preprocess, 113.4ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 0, 91.9ms
# Speed: 1.3ms preprocess, 91.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-bishop, 1 black-king, 1 black-knight, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 4 white-pawns, 1 white-queen, 114.3ms
# Speed: 3.6ms preprocess, 114.3ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 0, 89.2ms
# Speed: 2.0ms preprocess, 89.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-bishop, 1 black-king, 1 black-knight, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 4 white-pawns, 1 white-queen, 116.4ms
# Speed: 3.0ms preprocess, 116.4ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 0, 91.1ms
# Speed: 2.6ms preprocess, 91.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-king, 1 black-knight, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 4 white-pawns, 1 white-queen, 108.3ms
# Speed: 3.0ms preprocess, 108.3ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 89.5ms
# Speed: 2.0ms preprocess, 89.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-king, 1 black-knight, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 4 white-pawns, 1 white-queen, 107.0ms
# Speed: 3.7ms preprocess, 107.0ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 87.7ms
# Speed: 2.6ms preprocess, 87.7ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-king, 1 black-knight, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 4 white-pawns, 1 white-queen, 106.3ms
# Speed: 2.7ms preprocess, 106.3ms inference, 1.1ms postprocess per image at shape (1, 3, 800, 800)
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 87.0ms
# Speed: 2.0ms preprocess, 87.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-king, 1 black-knight, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 4 white-pawns, 1 white-queen, 110.3ms
# Speed: 3.0ms preprocess, 110.3ms inference, 1.6ms postprocess per image at shape (1, 3, 800, 800)
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 87.2ms
# Speed: 2.0ms preprocess, 87.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-king, 1 black-knight, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 4 white-pawns, 1 white-queen, 111.4ms
# Speed: 3.5ms preprocess, 111.4ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 87.2ms
# Speed: 2.0ms preprocess, 87.2ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-king, 1 black-knight, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 4 white-pawns, 1 white-queen, 114.1ms
# Speed: 3.0ms preprocess, 114.1ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 800)
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 91.6ms
# Speed: 2.0ms preprocess, 91.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-king, 1 black-knight, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 4 white-pawns, 1 white-queen, 103.0ms
# Speed: 3.2ms preprocess, 103.0ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 85.9ms
# Speed: 2.1ms preprocess, 85.9ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-king, 1 black-knight, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 4 white-pawns, 1 white-queen, 107.5ms
# Speed: 2.8ms preprocess, 107.5ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 800)
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 87.8ms
# Speed: 2.0ms preprocess, 87.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-king, 1 black-knight, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 4 white-pawns, 1 white-queen, 106.2ms
# Speed: 3.6ms preprocess, 106.2ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 800)
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 85.0ms
# Speed: 2.0ms preprocess, 85.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-king, 1 black-knight, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 4 white-pawns, 1 white-queen, 104.7ms
# Speed: 3.0ms preprocess, 104.7ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 94.3ms
# Speed: 2.0ms preprocess, 94.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-king, 1 black-knight, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 4 white-pawns, 1 white-queen, 107.2ms
# Speed: 2.0ms preprocess, 107.2ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 97.7ms
# Speed: 2.1ms preprocess, 97.7ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-king, 1 black-knight, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 4 white-pawns, 1 white-queen, 106.7ms
# Speed: 3.0ms preprocess, 106.7ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 89.7ms
# Speed: 2.1ms preprocess, 89.7ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-king, 1 black-knight, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 4 white-pawns, 1 white-queen, 107.0ms
# Speed: 2.7ms preprocess, 107.0ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 800)
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 92.1ms
# Speed: 2.6ms preprocess, 92.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-king, 1 black-knight, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 4 white-pawns, 1 white-queen, 113.7ms
# Speed: 2.0ms preprocess, 113.7ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 800)
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 100.7ms
# Speed: 2.0ms preprocess, 100.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-king, 1 black-knight, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 4 white-pawns, 1 white-queen, 116.2ms
# Speed: 3.0ms preprocess, 116.2ms inference, 1.1ms postprocess per image at shape (1, 3, 800, 800)
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 89.3ms
# Speed: 1.0ms preprocess, 89.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-king, 1 black-knight, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 4 white-pawns, 1 white-queen, 114.0ms
# Speed: 2.6ms preprocess, 114.0ms inference, 0.2ms postprocess per image at shape (1, 3, 800, 800)
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 84.6ms
# Speed: 3.0ms preprocess, 84.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-king, 1 black-knight, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 4 white-pawns, 1 white-queen, 102.0ms
# Speed: 3.0ms preprocess, 102.0ms inference, 1.2ms postprocess per image at shape (1, 3, 800, 800)
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 87.2ms
# Speed: 2.0ms preprocess, 87.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-king, 1 black-knight, 4 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 4 white-pawns, 1 white-queen, 106.3ms
# Speed: 3.0ms preprocess, 106.3ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
# Error: Generated FEN is invalid.

# %%
model_path = os.path.join('.', 'runs', 'segment', 'train_CB', 'weights', 'best.pt')
model = YOLO(model_path)

model_path1 = os.path.join('.', 'runs', 'detect', 'train_GCP', 'weights', 'best.pt')
model1 = YOLO(model_path1)

video_path = "C:/Users/Daithoulung Rongmai/Videos/Screen Recordings/Screen Recording 2024-10-25 212252.mp4" #Enter the path to the video file
video = cv2.VideoCapture(video_path)

if not video.isOpened():
    print("Error: Could not open video stream.")
    exit()

stockfish=Stockfish("StockFish/stockfish-windows-x86-64-avx2.exe")

top_moves = []

while True:
    ret, frame = video.read()
    if not ret:
        print("Error: Failed to capture frame.")
        break

    results = model.predict(frame, conf=0.5)

    warping_done = False

    for result in results:
        
        if hasattr(result, 'masks') and result.masks is not None:
            masks = result.masks.data.cpu().numpy()  

            for i in range(masks.shape[0]):
                
                mask = masks[i]
                mask_binary = (mask * 255).astype(np.uint8)
                mask_binary_resized = cv2.resize(mask_binary, (frame.shape[1], frame.shape[0]), interpolation=cv2.INTER_NEAREST)
                masked_frame = cv2.bitwise_and(frame, frame, mask=mask_binary_resized)
                contours, _ = cv2.findContours(mask_binary_resized, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
                
                if contours:
                    
                    largest_contour = max(contours, key=cv2.contourArea)
                    epsilon = 0.02 * cv2.arcLength(largest_contour, True)
                    approx_corners = cv2.approxPolyDP(largest_contour, epsilon, True)

                    if len(approx_corners) == 4:
                        
                        src_pts = np.array([pt[0] for pt in approx_corners], dtype="float32")
                        dst_pts = np.array([[0, 0], [600, 0], [600, 600], [0, 600]], dtype="float32")
                        
                        M = cv2.getPerspectiveTransform(src_pts, dst_pts)
                        warped_frame = cv2.warpPerspective(masked_frame, M, (600, 600))
                        rotated_frame = cv2.rotate(warped_frame, cv2.ROTATE_90_CLOCKWISE)
                        mirrored_frame = cv2.flip(rotated_frame, 1)

                        grid_size = 600
                        rows, cols = 8, 8
                        cell_width = grid_size // cols
                        cell_height = grid_size // rows

                        img_with_grid = mirrored_frame.copy()
                        for r in range(1, rows):
                            y = r * cell_height
                            cv2.line(img_with_grid, (0, y), (grid_size, y), (255, 0, 0), 1)
                        for c in range(1, cols):
                            x = c * cell_width
                            cv2.line(img_with_grid, (x, 0), (x, grid_size), (255, 0, 0), 1)

                        warping_done = True
                    else:
                        print("Could not find 4 corners for perspective transformation.")
                else:
                    print("No contours found for the mask.")
        else:
            print("No masks found in the results.")
    
    if not warping_done:
        for result in results:
            if hasattr(result, 'boxes') and result.boxes is not None:
                boxes = result.boxes.xyxy.cpu().numpy() 
                
                if len(boxes) > 0:
                    print("in")
                    x_min, y_min, x_max, y_max = boxes[0]
                    src_pts = np.array([[x_min, y_min], [x_max, y_min], [x_max, y_max], [x_min, y_max]], dtype="float32")
                    dst_pts = np.array([[0, 0], [600, 0], [600, 600], [0, 600]], dtype="float32")

                    M = cv2.getPerspectiveTransform(src_pts, dst_pts)
                    warped_frame = cv2.warpPerspective(frame, M, (600, 600))
                    rotated_frame = cv2.rotate(warped_frame, cv2.ROTATE_90_CLOCKWISE)
                    mirrored_frame = cv2.flip(rotated_frame, 1)

                    grid_size = 600
                    rows, cols = 8, 8
                    cell_width = grid_size // cols
                    cell_height = grid_size // rows
                    
                    img_with_grid = mirrored_frame.copy()
                    print(img_with_grid)
                    for r in range(1, rows):
                        y = r * cell_height
                        cv2.line(img_with_grid, (0, y), (grid_size, y), (255, 0, 0), 1)
                    for c in range(1, cols):
                        x = c * cell_width
                        cv2.line(img_with_grid, (x, 0), (x, grid_size), (255, 0, 0), 1)
                        
                    warping_done = True
                    break

    if not warping_done:
        frameResized = cv2.resize(frame, (600, 600))
        cv2.imshow("Chessboard", frameResized)
            
    else:
        columns = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h']
        rows_labels = ['1', '2', '3', '4', '5', '6', '7', '8']
        rows_labels.reverse()
    
        img_with_labels = img_with_grid.copy()
    
        for i in range(rows):
            for j in range(cols):
                x = i * cell_width
                y = j * cell_height
        
                label = columns[i] + rows_labels[j]
    
                text_x = x + cell_width // 2 - 15 
                text_y = y + cell_height // 2 + 15
        
                cv2.putText(img_with_labels, label, (text_x, text_y), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 0, 255), 2)
    
        res = img_with_labels.copy()
    
        piece_positions = {}
        
        results1 = model1.predict(mirrored_frame, conf=0.7)
        
        for result in results1:
            
            boxes = result.boxes.xyxy.cpu().numpy()
            classes = result.boxes.cls.cpu().numpy()
            names = result.names
            
            for box,class_id in zip(boxes,classes):
                
                x_min,y_min,x_max,y_max = box
                center_x = (x_min + x_max) / 2
                center_y = ((y_min + y_max) / 2)
                
                grid_col = int(center_x // cell_width)
                grid_row = int(center_y // cell_height)
                
                if 0 <= grid_col < cols and 0 <= grid_row < rows:
                    
                    grid_label = columns[grid_col] + rows_labels[grid_row]
                    piece_positions[grid_label] = names[int(class_id)]
                    
                    cv2.circle(res, (int(center_x), int(center_y)), 5, (255, 0, 0), -1)
                    cv2.putText(res, grid_label, (int(center_x)-10, int(center_y)-15), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 0, 255), 2)
    
        piece_map = {
            'white-rook': chess.Piece(chess.ROOK, chess.WHITE),
            'white-knight': chess.Piece(chess.KNIGHT, chess.WHITE),
            'white-bishop': chess.Piece(chess.BISHOP, chess.WHITE),
            'white-queen': chess.Piece(chess.QUEEN, chess.WHITE),
            'white-king': chess.Piece(chess.KING, chess.WHITE),
            'white-pawn': chess.Piece(chess.PAWN, chess.WHITE),
            'black-rook': chess.Piece(chess.ROOK, chess.BLACK),
            'black-knight': chess.Piece(chess.KNIGHT, chess.BLACK),
            'black-bishop': chess.Piece(chess.BISHOP, chess.BLACK),
            'black-queen': chess.Piece(chess.QUEEN, chess.BLACK),
            'black-king': chess.Piece(chess.KING, chess.BLACK),
            'black-pawn': chess.Piece(chess.PAWN, chess.BLACK),
        }
        
        def set_up_board(board, piece_positions, top_moves):
    
            try:
                for position, piece_description in piece_positions.items():
                    piece = piece_map.get(piece_description)
                    if piece:
                        square = chess.parse_square(position)
                        board.set_piece_at(square, piece)
                    else:
                        raise ValueError(f"Invalid piece description: {piece_description}")
            except Exception as e:
                print(f"Error setting up board: {e}")
                return top_moves
        
            fen_string = board.fen()

            try:
                new_board = chess.Board(fen_string)
                if not new_board.is_valid():
                    raise ValueError("Generated FEN is invalid.")
            except ValueError as e:
                print(f"Error: {e}")
                return top_moves 

            board = new_board
            
            try:
                stockfish.set_fen_position(board.fen())
                top_moves = stockfish.get_top_moves(1)
            except Exception as e:
                print(f"Stockfish error: {e}")
            
            return top_moves
            
        board = chess.Board(None)
        board.turn = chess.WHITE
        top_moves = set_up_board(board, piece_positions, top_moves)
        
        img_with_Ans = img_with_grid.copy()
        for move in top_moves:
            start_label = move['Move'][:2]  
            end_label = move['Move'][2:]
            
            for i in range(rows):
                for j in range(cols):
                    x = i * cell_width
                    y = j * cell_height
                    label = columns[i] + rows_labels[j]
                    
                    text_x = x + cell_width // 2
                    text_y = y + cell_height // 2
                    
                    if label == start_label:
                        start_x = text_x
                        start_y = text_y
                        cv2.circle(img_with_Ans, (int(text_x), int(text_y)), 5, (0, 0, 255), -1)
                        cv2.putText(img_with_Ans, label, (text_x, text_y), cv2.FONT_HERSHEY_SIMPLEX, 1, (100, 0, 255), 2)
                    
                    if label == end_label:
                        end_x = text_x
                        end_y = text_y
                        cv2.circle(img_with_Ans, (int(text_x), int(text_y)), 5, (0, 0, 255), -1)
                        cv2.putText(img_with_Ans, label, (text_x, text_y), cv2.FONT_HERSHEY_SIMPLEX, 1, (100, 0, 255), 2)
            
            cv2.arrowedLine(img_with_Ans, (start_x, start_y), (end_x, end_y), (255, 0, 0), 1, tipLength=0.1)
        
        
        cv2.imshow("Chessboard", img_with_Ans)
    
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

video.release()
cv2.destroyAllWindows()
# Out:
# 0: 800x800 1 0, 370.7ms
# Speed: 8.0ms preprocess, 370.7ms inference, 5.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 5 black-pawns, 1 black-rook, 1 white-king, 4 white-pawns, 1 white-queen, 1 white-rook, 224.8ms
# Speed: 8.5ms preprocess, 224.8ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 800x800 1 0, 321.6ms
# Speed: 7.0ms preprocess, 321.6ms inference, 3.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 5 black-pawns, 1 black-rook, 1 white-king, 4 white-pawns, 1 white-queen, 1 white-rook, 225.1ms
# Speed: 8.0ms preprocess, 225.1ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 800x800 1 0, 296.8ms
# Speed: 8.0ms preprocess, 296.8ms inference, 2.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 5 black-pawns, 1 black-rook, 1 white-king, 4 white-pawns, 1 white-queen, 1 white-rook, 218.4ms
# Speed: 8.0ms preprocess, 218.4ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 800x800 1 0, 288.6ms
# Speed: 8.0ms preprocess, 288.6ms inference, 2.1ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 5 black-pawns, 1 black-rook, 1 white-king, 4 white-pawns, 1 white-queen, 1 white-rook, 216.4ms
# Speed: 7.6ms preprocess, 216.4ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 800x800 1 0, 295.5ms
# Speed: 6.0ms preprocess, 295.5ms inference, 3.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 5 black-pawns, 1 black-rook, 1 white-king, 4 white-pawns, 1 white-queen, 1 white-rook, 111.5ms
# Speed: 4.0ms preprocess, 111.5ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 800x800 1 0, 161.2ms
# Speed: 4.5ms preprocess, 161.2ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 5 black-pawns, 1 black-rook, 1 white-king, 4 white-pawns, 1 white-queen, 1 white-rook, 123.1ms
# Speed: 4.0ms preprocess, 123.1ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 800x800 1 0, 144.5ms
# Speed: 5.0ms preprocess, 144.5ms inference, 2.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 5 black-pawns, 1 black-rook, 1 white-king, 4 white-pawns, 1 white-queen, 1 white-rook, 112.5ms
# Speed: 3.0ms preprocess, 112.5ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 800x800 1 0, 179.1ms
# Speed: 4.0ms preprocess, 179.1ms inference, 2.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 5 black-pawns, 1 black-rook, 1 white-king, 4 white-pawns, 1 white-queen, 1 white-rook, 138.5ms
# Speed: 4.0ms preprocess, 138.5ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 800x800 1 0, 185.8ms
# Speed: 4.0ms preprocess, 185.8ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 5 black-pawns, 1 black-rook, 1 white-king, 4 white-pawns, 1 white-queen, 1 white-rook, 137.5ms
# Speed: 4.0ms preprocess, 137.5ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 800x800 1 0, 198.4ms
# Speed: 4.0ms preprocess, 198.4ms inference, 2.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 5 black-pawns, 1 black-rook, 1 white-king, 4 white-pawns, 1 white-queen, 1 white-rook, 146.5ms
# Speed: 4.0ms preprocess, 146.5ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 800x800 1 0, 182.5ms
# Speed: 4.0ms preprocess, 182.5ms inference, 2.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 5 black-pawns, 1 black-rook, 1 white-king, 4 white-pawns, 1 white-queen, 1 white-rook, 149.0ms
# Speed: 4.0ms preprocess, 149.0ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 800x800 1 0, 128.1ms
# Speed: 5.0ms preprocess, 128.1ms inference, 2.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 5 black-pawns, 1 black-rook, 1 white-king, 4 white-pawns, 1 white-queen, 1 white-rook, 89.2ms
# Speed: 3.9ms preprocess, 89.2ms inference, 0.9ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 800x800 1 0, 141.9ms
# Speed: 3.9ms preprocess, 141.9ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 5 black-pawns, 1 black-rook, 1 white-king, 4 white-pawns, 1 white-queen, 1 white-rook, 92.9ms
# Speed: 3.0ms preprocess, 92.9ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 800x800 1 0, 128.3ms
# Speed: 4.1ms preprocess, 128.3ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 5 black-pawns, 1 black-rook, 1 white-king, 4 white-pawns, 1 white-queen, 1 white-rook, 91.9ms
# Speed: 4.0ms preprocess, 91.9ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 800x800 1 0, 120.8ms
# Speed: 5.0ms preprocess, 120.8ms inference, 2.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 5 black-pawns, 1 black-rook, 1 white-king, 4 white-pawns, 1 white-queen, 1 white-rook, 89.4ms
# Speed: 3.0ms preprocess, 89.4ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 800x800 1 0, 121.1ms
# Speed: 4.0ms preprocess, 121.1ms inference, 2.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 5 black-pawns, 1 black-rook, 1 white-king, 4 white-pawns, 1 white-queen, 1 white-rook, 89.2ms
# Speed: 3.9ms preprocess, 89.2ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 800x800 1 0, 125.6ms
# Speed: 5.1ms preprocess, 125.6ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 5 black-pawns, 1 black-rook, 1 white-king, 4 white-pawns, 1 white-queen, 1 white-rook, 95.1ms
# Speed: 3.1ms preprocess, 95.1ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 800x800 1 0, 124.5ms
# Speed: 3.1ms preprocess, 124.5ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 5 black-pawns, 1 black-rook, 1 white-king, 4 white-pawns, 1 white-queen, 1 white-rook, 89.7ms
# Speed: 3.0ms preprocess, 89.7ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 800x800 1 0, 119.9ms
# Speed: 4.0ms preprocess, 119.9ms inference, 1.1ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 5 black-pawns, 1 black-rook, 1 white-king, 4 white-pawns, 1 white-queen, 1 white-rook, 83.6ms
# Speed: 4.0ms preprocess, 83.6ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 800x800 1 0, 114.9ms
# Speed: 2.9ms preprocess, 114.9ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 5 black-pawns, 1 black-rook, 1 white-king, 4 white-pawns, 1 white-queen, 1 white-rook, 83.8ms
# Speed: 3.0ms preprocess, 83.8ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 800x800 1 0, 119.0ms
# Speed: 4.0ms preprocess, 119.0ms inference, 2.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 5 black-pawns, 1 black-rook, 1 white-king, 4 white-pawns, 1 white-queen, 1 white-rook, 99.6ms
# Speed: 3.7ms preprocess, 99.6ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 800x800 1 0, 126.7ms
# Speed: 4.0ms preprocess, 126.7ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 5 black-pawns, 1 black-rook, 1 white-king, 4 white-pawns, 1 white-queen, 1 white-rook, 94.7ms
# Speed: 4.0ms preprocess, 94.7ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 800x800 1 0, 129.5ms
# Speed: 4.0ms preprocess, 129.5ms inference, 1.1ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 5 black-pawns, 1 black-rook, 1 white-king, 4 white-pawns, 1 white-queen, 1 white-rook, 90.7ms
# Speed: 4.0ms preprocess, 90.7ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 800x800 1 0, 121.7ms
# Speed: 4.0ms preprocess, 121.7ms inference, 1.9ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 5 black-pawns, 1 black-rook, 1 white-king, 4 white-pawns, 1 white-queen, 1 white-rook, 90.7ms
# Speed: 4.1ms preprocess, 90.7ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 800x800 1 0, 129.3ms
# Speed: 4.0ms preprocess, 129.3ms inference, 2.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 5 black-pawns, 1 black-rook, 1 white-king, 4 white-pawns, 1 white-queen, 1 white-rook, 99.8ms
# Speed: 3.5ms preprocess, 99.8ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 800x800 1 0, 134.6ms
# Speed: 3.3ms preprocess, 134.6ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 5 black-pawns, 1 black-rook, 1 white-king, 4 white-pawns, 1 white-queen, 1 white-rook, 95.5ms
# Speed: 3.0ms preprocess, 95.5ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 800x800 1 0, 127.3ms
# Speed: 4.0ms preprocess, 127.3ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 5 black-pawns, 1 black-rook, 1 white-king, 4 white-pawns, 1 white-queen, 1 white-rook, 99.4ms
# Speed: 3.1ms preprocess, 99.4ms inference, 0.9ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 800x800 1 0, 143.4ms
# Speed: 4.0ms preprocess, 143.4ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 5 black-pawns, 1 black-rook, 1 white-king, 4 white-pawns, 1 white-queen, 1 white-rook, 106.2ms
# Speed: 4.0ms preprocess, 106.2ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 800x800 1 0, 202.5ms
# Speed: 3.0ms preprocess, 202.5ms inference, 2.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 5 black-pawns, 1 black-rook, 1 white-king, 4 white-pawns, 1 white-queen, 1 white-rook, 115.5ms
# Speed: 4.0ms preprocess, 115.5ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
