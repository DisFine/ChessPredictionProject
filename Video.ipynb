# %%
import matplotlib.pyplot as plt
from PIL import Image
import cv2
import numpy as np
import os
from ultralytics import YOLO
import chess
from stockfish import Stockfish

# %%
model_path = os.path.join('.', 'runs', 'segment', 'train_CB', 'weights', 'best.pt')
model = YOLO(model_path)

model_path1 = os.path.join('.', 'runs', 'detect', 'train_GCP', 'weights', 'best.pt')
model1 = YOLO(model_path1)

video = cv2.VideoCapture(0)
address = "https://192.168.1.5:8080/video" #ADD CUSTOM ADDRESS HERE!
video.open(address)

if not video.isOpened():
    print("Error: Could not open video stream.")
    exit()

stockfish=Stockfish("StockFish/stockfish-windows-x86-64-avx2.exe")

top_moves = []

while True:
    ret, frame = video.read()

    if not ret:
        print("Error: Failed to capture frame.")
        break

    results = model.predict(frame, conf=0.5)

    warping_done = False

    for result in results:
        
        if hasattr(result, 'masks') and result.masks is not None:
            masks = result.masks.data.cpu().numpy()  

            for i in range(masks.shape[0]):
                
                mask = masks[i]
                mask_binary = (mask * 255).astype(np.uint8)
                mask_binary_resized = cv2.resize(mask_binary, (frame.shape[1], frame.shape[0]), interpolation=cv2.INTER_NEAREST)
                masked_frame = cv2.bitwise_and(frame, frame, mask=mask_binary_resized)
                contours, _ = cv2.findContours(mask_binary_resized, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
                
                if contours:
                    
                    largest_contour = max(contours, key=cv2.contourArea)
                    epsilon = 0.02 * cv2.arcLength(largest_contour, True)
                    approx_corners = cv2.approxPolyDP(largest_contour, epsilon, True)

                    if len(approx_corners) == 4:
                        
                        src_pts = np.array([pt[0] for pt in approx_corners], dtype="float32")
                        dst_pts = np.array([[0, 0], [600, 0], [600, 600], [0, 600]], dtype="float32")
                        
                        M = cv2.getPerspectiveTransform(src_pts, dst_pts)
                        warped_frame = cv2.warpPerspective(masked_frame, M, (600, 600))
                        rotated_frame = cv2.rotate(warped_frame, cv2.ROTATE_90_CLOCKWISE)
                        mirrored_frame = cv2.flip(rotated_frame, 1)

                        grid_size = 600
                        rows, cols = 8, 8
                        cell_width = grid_size // cols
                        cell_height = grid_size // rows

                        img_with_grid = mirrored_frame.copy()
                        for r in range(1, rows):
                            y = r * cell_height
                            cv2.line(img_with_grid, (0, y), (grid_size, y), (255, 0, 0), 1)
                        for c in range(1, cols):
                            x = c * cell_width
                            cv2.line(img_with_grid, (x, 0), (x, grid_size), (255, 0, 0), 1)

                        warping_done = True
                    else:
                        print("Could not find 4 corners for perspective transformation.")
                else:
                    print("No contours found for the mask.")
        else:
            print("No masks found in the results.")
    
    if not warping_done:
        for result in results:
            if hasattr(result, 'boxes') and result.boxes is not None:
                boxes = result.boxes.xyxy.cpu().numpy() 
                
                if len(boxes) > 0:
                    print("in")
                    x_min, y_min, x_max, y_max = boxes[0]
                    src_pts = np.array([[x_min, y_min], [x_max, y_min], [x_max, y_max], [x_min, y_max]], dtype="float32")
                    dst_pts = np.array([[0, 0], [600, 0], [600, 600], [0, 600]], dtype="float32")

                    M = cv2.getPerspectiveTransform(src_pts, dst_pts)
                    warped_frame = cv2.warpPerspective(frame, M, (600, 600))
                    rotated_frame = cv2.rotate(warped_frame, cv2.ROTATE_90_CLOCKWISE)
                    mirrored_frame = cv2.flip(rotated_frame, 1)

                    grid_size = 600
                    rows, cols = 8, 8
                    cell_width = grid_size // cols
                    cell_height = grid_size // rows
                    
                    img_with_grid = mirrored_frame.copy()
                    print(img_with_grid)
                    for r in range(1, rows):
                        y = r * cell_height
                        cv2.line(img_with_grid, (0, y), (grid_size, y), (255, 0, 0), 1)
                    for c in range(1, cols):
                        x = c * cell_width
                        cv2.line(img_with_grid, (x, 0), (x, grid_size), (255, 0, 0), 1)
                        
                    warping_done = True
                    break

    if not warping_done:
        frameResized = cv2.resize(frame, (600, 600))
        cv2.imshow("Chessboard", frameResized)
            
    else:
        columns = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h']
        rows_labels = ['1', '2', '3', '4', '5', '6', '7', '8']
        rows_labels.reverse()
    
        img_with_labels = img_with_grid.copy()
    
        for i in range(rows):
            for j in range(cols):
                x = i * cell_width
                y = j * cell_height
        
                label = columns[i] + rows_labels[j]
    
                text_x = x + cell_width // 2 - 15 
                text_y = y + cell_height // 2 + 15
        
                cv2.putText(img_with_labels, label, (text_x, text_y), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 0, 255), 2)
    
        res = img_with_labels.copy()
    
        piece_positions = {}
        
        results1 = model1.predict(mirrored_frame, conf=0.7)
        
        for result in results1:
            
            boxes = result.boxes.xyxy.cpu().numpy()
            classes = result.boxes.cls.cpu().numpy()
            names = result.names
            
            for box,class_id in zip(boxes,classes):
                
                x_min,y_min,x_max,y_max = box
                center_x = (x_min + x_max) / 2
                center_y = ((y_min + y_max) / 2)
                
                grid_col = int(center_x // cell_width)
                grid_row = int(center_y // cell_height)
                
                if 0 <= grid_col < cols and 0 <= grid_row < rows:
                    
                    grid_label = columns[grid_col] + rows_labels[grid_row]
                    piece_positions[grid_label] = names[int(class_id)]
                    
                    cv2.circle(res, (int(center_x), int(center_y)), 5, (255, 0, 0), -1)
                    cv2.putText(res, grid_label, (int(center_x)-10, int(center_y)-15), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 0, 255), 2)
    
        piece_map = {
            'white-rook': chess.Piece(chess.ROOK, chess.WHITE),
            'white-knight': chess.Piece(chess.KNIGHT, chess.WHITE),
            'white-bishop': chess.Piece(chess.BISHOP, chess.WHITE),
            'white-queen': chess.Piece(chess.QUEEN, chess.WHITE),
            'white-king': chess.Piece(chess.KING, chess.WHITE),
            'white-pawn': chess.Piece(chess.PAWN, chess.WHITE),
            'black-rook': chess.Piece(chess.ROOK, chess.BLACK),
            'black-knight': chess.Piece(chess.KNIGHT, chess.BLACK),
            'black-bishop': chess.Piece(chess.BISHOP, chess.BLACK),
            'black-queen': chess.Piece(chess.QUEEN, chess.BLACK),
            'black-king': chess.Piece(chess.KING, chess.BLACK),
            'black-pawn': chess.Piece(chess.PAWN, chess.BLACK),
        }
        
        def set_up_board(piece_positions, top_moves):
            board = chess.Board(None)
            try:
                for position, piece_description in piece_positions.items():
                    piece = piece_map.get(piece_description)
                    if piece:
                        square = chess.parse_square(position)
                        board.set_piece_at(square, piece)
                    else:
                        raise ValueError(f"Invalid piece description: {piece_description}")
            except Exception as e:
                print(f"Error setting up board: {e}")
                return top_moves
        
            fen_string = board.fen()

            try:
                board = chess.Board(fen_string)
                board.turn = chess.WHITE #CHANGE COLOR
                if not board.is_valid():
                    raise ValueError("Generated FEN is invalid.")
            except ValueError as e:
                print(f"Error: {e}")
                return top_moves 
                
            try:
                stockfish.set_fen_position(board.fen())
                top_moves = stockfish.get_top_moves(1)
            except Exception as e:
                print(f"Stockfish error: {e}")
            
            return top_moves
            
        top_moves = set_up_board(piece_positions, top_moves)
        
        img_with_Ans = img_with_grid.copy()
        for move in top_moves:
            start_label = move['Move'][:2]  
            end_label = move['Move'][2:]
            start_x = start_y = end_x = end_y = None
            
            for i in range(rows):
                for j in range(cols):
                    x = i * cell_width
                    y = j * cell_height
                    label = columns[i] + rows_labels[j]
                    
                    text_x = x + cell_width // 2
                    text_y = y + cell_height // 2
                    
                    if label == start_label:
                        start_x = text_x
                        start_y = text_y
                        cv2.circle(img_with_Ans, (int(text_x), int(text_y)), 5, (0, 0, 255), -1)
                        cv2.putText(img_with_Ans, label, (text_x, text_y), cv2.FONT_HERSHEY_SIMPLEX, 1, (100, 0, 255), 2)
                    
                    if label == end_label:
                        end_x = text_x
                        end_y = text_y
                        cv2.circle(img_with_Ans, (int(text_x), int(text_y)), 5, (0, 0, 255), -1)
                        cv2.putText(img_with_Ans, label, (text_x, text_y), cv2.FONT_HERSHEY_SIMPLEX, 1, (100, 0, 255), 2)
            
            cv2.arrowedLine(img_with_Ans, (start_x, start_y), (end_x, end_y), (255, 0, 0), 1, tipLength=0.1)
        
        
        cv2.imshow("Chessboard", img_with_Ans)
    
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
    
video.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x800 1 0, 45.8ms
# Speed: 3.0ms preprocess, 45.8ms inference, 73.3ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-pawn, 2 white-pawns, 9.0ms
# Speed: 4.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 8.0ms
# Speed: 3.0ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-bishop, 3 black-pawns, 1 black-queen, 2 white-pawns, 8.0ms
# Speed: 4.3ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 800, 800)
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 8.1ms
# Speed: 3.5ms preprocess, 8.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-bishop, 3 black-pawns, 2 black-queens, 1 white-king, 3 white-pawns, 9.0ms
# Speed: 3.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 800, 800)
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 7.6ms
# Speed: 2.5ms preprocess, 7.6ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-bishop, 3 black-pawns, 2 black-queens, 1 white-king, 3 white-pawns, 8.5ms
# Speed: 4.0ms preprocess, 8.5ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 8.5ms
# Speed: 3.0ms preprocess, 8.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-bishop, 3 black-pawns, 1 black-queen, 1 white-king, 3 white-pawns, 9.3ms
# Speed: 3.0ms preprocess, 9.3ms inference, 3.5ms postprocess per image at shape (1, 3, 800, 800)
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 9.0ms
# Speed: 3.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-bishop, 3 black-pawns, 1 black-queen, 1 white-king, 3 white-pawns, 9.0ms
# Speed: 3.5ms preprocess, 9.0ms inference, 2.5ms postprocess per image at shape (1, 3, 800, 800)
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 9.5ms
# Speed: 3.0ms preprocess, 9.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-bishop, 3 black-pawns, 1 black-queen, 1 white-king, 3 white-pawns, 9.4ms
# Speed: 3.6ms preprocess, 9.4ms inference, 2.0ms postprocess per image at shape (1, 3, 800, 800)
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 9.1ms
# Speed: 4.0ms preprocess, 9.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-bishop, 3 black-pawns, 2 black-queens, 1 white-king, 3 white-pawns, 8.0ms
# Speed: 3.0ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-bishop, 3 black-pawns, 2 black-queens, 1 white-king, 3 white-pawns, 9.0ms
# Speed: 4.2ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 7.5ms
# Speed: 3.6ms preprocess, 7.5ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-bishop, 3 black-pawns, 2 black-queens, 1 white-king, 3 white-pawns, 8.5ms
# Speed: 3.0ms preprocess, 8.5ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 7.0ms
# Speed: 2.9ms preprocess, 7.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-bishop, 3 black-pawns, 2 black-queens, 1 white-king, 3 white-pawns, 9.8ms
# Speed: 4.0ms preprocess, 9.8ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 8.0ms
# Speed: 2.1ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-bishop, 3 black-pawns, 2 black-queens, 1 white-king, 3 white-pawns, 9.5ms
# Speed: 4.0ms preprocess, 9.5ms inference, 1.5ms postprocess per image at shape (1, 3, 800, 800)
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-bishop, 3 black-pawns, 2 black-queens, 1 white-king, 3 white-pawns, 9.2ms
# Speed: 3.7ms preprocess, 9.2ms inference, 2.5ms postprocess per image at shape (1, 3, 800, 800)
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 10.0ms
# Speed: 4.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-bishop, 3 black-pawns, 1 black-queen, 1 white-king, 3 white-pawns, 8.0ms
# Speed: 4.9ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 800, 800)
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 7.5ms
# Speed: 2.5ms preprocess, 7.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-bishop, 1 black-king, 3 black-pawns, 1 black-queen, 1 white-king, 3 white-pawns, 11.0ms
# Speed: 3.1ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 7.5ms
# Speed: 3.1ms preprocess, 7.5ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-bishop, 1 black-king, 3 black-pawns, 1 black-queen, 1 white-king, 3 white-pawns, 10.2ms
# Speed: 4.0ms preprocess, 10.2ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 8.0ms
# Speed: 3.0ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-bishop, 1 black-king, 3 black-pawns, 1 black-queen, 1 white-king, 3 white-pawns, 9.0ms
# Speed: 4.0ms preprocess, 9.0ms inference, 2.5ms postprocess per image at shape (1, 3, 800, 800)
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 8.5ms
# Speed: 3.0ms preprocess, 8.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-bishop, 1 black-king, 3 black-pawns, 2 black-queens, 1 white-king, 3 white-pawns, 8.5ms
# Speed: 4.0ms preprocess, 8.5ms inference, 1.5ms postprocess per image at shape (1, 3, 800, 800)
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 8.2ms
# Speed: 3.0ms preprocess, 8.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-bishop, 1 black-king, 3 black-pawns, 1 black-queen, 1 white-bishop, 1 white-king, 3 white-pawns, 9.0ms
# Speed: 5.5ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 8.0ms
# Speed: 2.5ms preprocess, 8.0ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-bishop, 1 black-king, 3 black-pawns, 1 black-queen, 1 white-king, 3 white-pawns, 1 white-queen, 8.5ms
# Speed: 4.0ms preprocess, 8.5ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 0, 7.5ms
# Speed: 3.0ms preprocess, 7.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 3 black-pawns, 2 black-queens, 1 white-king, 3 white-pawns, 9.0ms
# Speed: 3.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-bishop, 1 black-king, 5 black-pawns, 1 black-queen, 1 white-bishop, 1 white-king, 3 white-pawns, 1 white-queen, 9.4ms
# Speed: 3.0ms preprocess, 9.4ms inference, 1.5ms postprocess per image at shape (1, 3, 800, 800)
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 7.5ms
# Speed: 3.5ms preprocess, 7.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-bishop, 1 black-king, 5 black-pawns, 1 black-queen, 1 white-bishop, 1 white-king, 3 white-pawns, 1 white-queen, 9.3ms
# Speed: 3.5ms preprocess, 9.3ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-bishop, 1 black-king, 5 black-pawns, 1 black-queen, 1 white-bishop, 1 white-king, 3 white-pawns, 1 white-queen, 9.0ms
# Speed: 3.0ms preprocess, 9.0ms inference, 1.5ms postprocess per image at shape (1, 3, 800, 800)
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 9.0ms
# Speed: 2.5ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-bishop, 1 black-king, 6 black-pawns, 1 black-queen, 1 white-bishop, 1 white-king,
ms postprocess per image at shape (1, 3, 800, 800)
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 7.5ms
# Speed: 3.9ms preprocess, 7.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-bishop, 1 black-king, 4 black-pawns, 1 black-queen, 1 white-bishop, 1 white-king, 3 white-pawns, 1 white-queen, 7.8ms
# Speed: 4.0ms preprocess, 7.8ms inference, 2.0ms postprocess per image at shape (1, 3, 800, 800)
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 8.6ms
# Speed: 2.5ms preprocess, 8.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-bishop, 1 black-king, 5 black-pawns, 1 black-queen, 1 white-bishop, 1 white-king, 3 white-pawns, 1 white-queen, 9.0ms
# Speed: 3.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-bishop, 1 black-king, 5 black-pawns, 1 black-queen, 1 white-bishop, 1 white-king, 3 white-pawns, 1 white-queen, 8.5ms
# Speed: 3.0ms preprocess, 8.5ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 8.1ms
# Speed: 3.0ms preprocess, 8.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-bishop, 1 black-king, 5 black-pawns, 1 black-queen, 1 white-bishop, 1 white-king, 3 white-pawns, 1 white-queen, 8.0ms
# Speed: 4.2ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 800, 800)
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 9.1ms
# Speed: 2.0ms preprocess, 9.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-bishop, 1 black-king, 5 black-pawns, 1 black-queen, 1 white-bishop, 1 white-king, 3 white-pawns, 1 white-queen, 9.0ms
# Speed: 4.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 9.3ms
# Speed: 2.1ms preprocess, 9.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-bishop, 1 black-king, 5 black-pawns, 1 black-queen, 1 white-bishop, 1 white-king, 3 white-pawns, 1 white-queen, 9.1ms
# Speed: 4.0ms preprocess, 9.1ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 8.0ms
# Speed: 3.0ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-bishop, 1 black-king, 5 black-pawns, 1 black-queen, 1 white-bishop, 1 white-king, 3 white-pawns, 1 white-queen, 9.0ms
# Speed: 4.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 7.6ms
# Speed: 3.0ms preprocess, 7.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-bishop, 1 black-king, 4 black-pawns, 1 black-queen, 1 white-bishop, 1 white-king, 3 white-pawns, 1 white-queen, 9.3ms
# Speed: 4.1ms preprocess, 9.3ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 7.8ms
# Speed: 3.0ms preprocess, 7.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-bishop, 1 black-king, 4 black-pawns, 1 black-queen, 1 white-bishop, 1 white-king, 3 white-pawns, 1 white-queen, 9.5ms
# Speed: 3.5ms preprocess, 9.5ms inference, 2.0ms postprocess per image at shape (1, 3, 800, 800)
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 7.0ms
# Speed: 3.0ms preprocess, 7.0ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-bishop, 1 black-king, 5 black-pawns, 1 black-queen, 1 white-bishop, 1 white-king, 3 white-pawns, 1 white-queen, 9.2ms
# Speed: 3.0ms preprocess, 9.2ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-bishop, 1 black-king, 5 black-pawns, 1 black-queen, 1 white-bishop, 1 white-king, 3 white-pawns, 1 white-queen, 9.1ms
# Speed: 4.0ms preprocess, 9.1ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 8.0ms
# Speed: 3.0ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-bishop, 1 black-king, 5 black-pawns, 1 black-queen, 1 white-bishop, 1 white-king, 3 white-pawns, 1 white-queen, 8.1ms
# Speed: 4.0ms preprocess, 8.1ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 9.3ms
# Speed: 3.0ms preprocess, 9.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-bishop, 1 black-king, 5 black-pawns, 1 black-queen, 1 white-bishop, 1 white-king, 3 white-pawns, 1 white-queen, 9.5ms
# Speed: 3.5ms preprocess, 9.5ms inference, 1.1ms postprocess per image at shape (1, 3, 800, 800)
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 8.3ms
# Speed: 2.0ms preprocess, 8.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-bishop, 1 black-king, 4 black-pawns, 1 black-queen, 1 white-bishop, 1 white-king, 3 white-pawns, 1 white-queen, 8.1ms
# Speed: 4.7ms preprocess, 8.1ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 7.3ms
# Speed: 2.2ms preprocess, 7.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-bishop, 1 black-king, 4 black-pawns, 1 black-queen, 1 white-bishop, 1 white-king, 3 white-pawns, 1 white-queen, 8.4ms
# Speed: 3.6ms preprocess, 8.4ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 8.2ms
# Speed: 3.0ms preprocess, 8.2ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-bishop, 1 black-king, 5 black-pawns, 1 black-queen, 1 white-bishop, 1 white-king, 3 white-pawns, 1 white-queen, 8.5ms
# Speed: 3.6ms preprocess, 8.5ms inference, 2.0ms postprocess per image at shape (1, 3, 800, 800)
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 8.1ms
# Speed: 2.3ms preprocess, 8.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-bishop, 1 black-king, 5 black-pawns, 1 black-queen, 1 white-bishop, 1 white-king, 3 white-pawns, 1 white-queen, 9.2ms
# Speed: 3.0ms preprocess, 9.2ms inference, 2.0ms postprocess per image at shape (1, 3, 800, 800)
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 8.7ms
# Speed: 2.6ms preprocess, 8.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-bishop, 1 black-king, 4 black-pawns, 1 black-queen, 1 white-bishop, 1 white-king, 3 white-pawns, 1 white-queen, 9.6ms
# Speed: 3.1ms preprocess, 9.6ms inference, 1.1ms postprocess per image at shape (1, 3, 800, 800)
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 7.7ms
# Speed: 2.0ms preprocess, 7.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-bishop, 1 black-king, 5 black-pawns, 1 black-queen, 1 white-bishop, 1 white-king, 3 white-pawns, 1 white-queen, 8.6ms
# Speed: 3.6ms preprocess, 8.6ms inference, 1.1ms postprocess per image at shape (1, 3, 800, 800)
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 8.5ms
# Speed: 2.6ms preprocess, 8.5ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-bishop, 1 black-king, 5 black-pawns, 1 black-queen, 1 white-bishop, 1 white-king, 3 white-pawns, 1 white-queen, 8.4ms
# Speed: 4.0ms preprocess, 8.4ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 8.4ms
# Speed: 2.3ms preprocess, 8.4ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-bishop, 1 black-king, 5 black-pawns, 1 black-queen, 1 white-bishop, 1 white-king, 3 white-pawns, 1 white-queen, 8.5ms
# Speed: 2.9ms preprocess, 8.5ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 7.6ms
# Speed: 3.0ms preprocess, 7.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-bishop, 1 black-king, 5 black-pawns, 1 black-queen, 1 white-bishop, 1 white-king, 3 white-pawns, 1 white-queen, 10.0ms
# Speed: 3.7ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 8.3ms
# Speed: 2.1ms preprocess, 8.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-bishop, 1 black-king, 5 black-pawns, 1 black-queen, 1 white-bishop, 1 white-king, 3 white-pawns, 1 white-queen, 9.5ms
# Speed: 4.2ms preprocess, 9.5ms inference, 0.7ms postprocess per image at shape (1, 3, 800, 800)
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 7.6ms
# Speed: 3.2ms preprocess, 7.6ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-bishop, 1 black-king, 5 black-pawns, 1 black-queen, 1 white-bishop, 1 white-king, 3 white-pawns, 1 white-queen, 10.8ms
# Speed: 2.1ms preprocess, 10.8ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 8.5ms
# Speed: 2.0ms preprocess, 8.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-bishop, 1 black-king, 5 black-pawns, 1 black-queen, 1 white-bishop, 1 white-king, 3 white-pawns, 1 white-queen, 8.6ms
# Speed: 3.5ms preprocess, 8.6ms inference, 1.5ms postprocess per image at shape (1, 3, 800, 800)
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 8.0ms
# Speed: 1.9ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-bishop, 1 black-king, 5 black-pawns, 1 black-queen, 1 white-bishop, 1 white-king, 3 white-pawns, 1 white-queen, 8.4ms
# Speed: 3.0ms preprocess, 8.4ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 9.3ms
# Speed: 2.0ms preprocess, 9.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-bishop, 1 black-king, 5 black-pawns, 1 black-queen, 1 white-bishop, 1 white-king, 3 white-pawns, 1 white-queen, 8.3ms
# Speed: 4.5ms preprocess, 8.3ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 7.9ms
# Speed: 2.6ms preprocess, 7.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-bishop, 1 black-king, 5 black-pawns, 1 black-queen, 1 white-bishop, 1 white-king, 3 white-pawns, 1 white-queen, 8.6ms
# Speed: 3.1ms preprocess, 8.6ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 8.1ms
# Speed: 2.7ms preprocess, 8.1ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-bishop, 1 black-king, 5 black-pawns, 1 black-queen, 1 white-bishop, 1 white-king, 3 white-pawns, 1 white-queen, 8.7ms
# Speed: 3.9ms preprocess, 8.7ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 9.5ms
# Speed: 4.0ms preprocess, 9.5ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-bishop, 1 black-king, 5 black-pawns, 1 black-queen, 1 white-bishop, 1 white-king, 3 white-pawns, 1 white-queen, 9.4ms
# Speed: 4.3ms preprocess, 9.4ms inference, 0.7ms postprocess per image at shape (1, 3, 800, 800)
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 7.9ms
# Speed: 2.0ms preprocess, 7.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-bishop, 1 black-king, 5 black-pawns, 1 black-queen, 1 white-bishop, 1 white-king, 3 white-pawns, 1 white-queen, 8.1ms
# Speed: 4.0ms preprocess, 8.1ms inference, 2.0ms postprocess per image at shape (1, 3, 800, 800)
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 8.2ms
# Speed: 2.0ms preprocess, 8.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-bishop, 1 black-king, 5 black-pawns, 1 black-queen, 1 white-bishop, 1 white-king, 3 white-pawns, 1 white-queen, 8.6ms
# Speed: 5.1ms preprocess, 8.6ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 8.2ms
# Speed: 3.1ms preprocess, 8.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-bishop, 1 black-king, 5 black-pawns, 1 black-queen, 1 white-bishop, 1 white-king, 3 white-pawns, 1 white-queen, 9.4ms
# Speed: 4.1ms preprocess, 9.4ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 9.0ms
# Speed: 3.5ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-bishop, 1 black-king, 5 black-pawns, 1 black-queen, 1 white-bishop, 1 white-king, 3 white-pawns, 1 white-queen, 9.7ms
# Speed: 3.6ms preprocess, 9.7ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 800)
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 8.2ms
# Speed: 2.0ms preprocess, 8.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-bishop, 1 black-king, 5 black-pawns, 1 black-queen, 1 white-bishop, 1 white-king, 3 white-pawns, 1 white-queen, 9.1ms
# Speed: 3.2ms preprocess, 9.1ms inference, 1.1ms postprocess per image at shape (1, 3, 800, 800)
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 7.2ms
# Speed: 2.0ms preprocess, 7.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-bishop, 1 black-king, 5 black-pawns, 1 black-queen, 1 white-bishop, 1 white-king, 3 white-pawns, 1 white-queen, 8.5ms
# Speed: 3.3ms preprocess, 8.5ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 800)
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 8.3ms
# Speed: 2.0ms preprocess, 8.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-bishop, 1 black-king, 5 black-pawns, 1 black-queen, 1 white-bishop, 1 white-king, 3 white-pawns, 1 white-queen, 8.1ms
# Speed: 3.6ms preprocess, 8.1ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 8.1ms
# Speed: 2.2ms preprocess, 8.1ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-bishop, 1 black-king, 5 black-pawns, 1 black-queen, 1 white-bishop, 1 white-king, 3 white-pawns, 1 white-queen, 9.5ms
# Speed: 3.1ms preprocess, 9.5ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0,
black-pawns, 1 black-queen, 1 white-bishop, 1 white-king, 3 white-pawns, 1 white-queen, 10.1ms
# Speed: 3.1ms preprocess, 10.1ms inference, 1.5ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 0, 11.1ms
# Speed: 3.0ms preprocess, 11.1ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-bishop, 1 black-king, 3 black-pawns, 1 black-queen, 1 white-bishop, 1 white-king, 3 white-pawns, 1 white-queen, 9.9ms
# Speed: 4.6ms preprocess, 9.9ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 0, 9.3ms
# Speed: 2.6ms preprocess, 9.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-bishop, 1 black-king, 3 black-pawns, 1 black-queen, 1 white-bishop, 1 white-king, 3 white-pawns, 1 white-queen, 9.5ms
# Speed: 4.0ms preprocess, 9.5ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 0, 8.3ms
# Speed: 4.0ms preprocess, 8.3ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-bishop, 1 black-king, 3 black-pawns, 1 black-queen, 1 white-bishop, 1 white-king, 3 white-pawns, 1 white-queen, 9.2ms
# Speed: 3.1ms preprocess, 9.2ms inference, 2.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 0, 9.4ms
# Speed: 2.0ms preprocess, 9.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-bishop, 1 black-king, 3 black-pawns, 1 black-queen, 1 white-bishop, 1 white-king, 3 white-pawns, 1 white-queen, 11.4ms
# Speed: 3.0ms preprocess, 11.4ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 0, 9.7ms
# Speed: 3.1ms preprocess, 9.7ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-bishop, 1 black-king, 3 black-pawns, 1 black-queen, 1 white-bishop, 1 white-king, 3 white-pawns, 1 white-queen, 11.0ms
# Speed: 5.0ms preprocess, 11.0ms inference, 1.6ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 0, 11.3ms
# Speed: 2.8ms preprocess, 11.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-bishop, 1 black-king, 3 black-pawns, 1 black-queen, 1 white-bishop, 1 white-king, 3 white-pawns, 1 white-queen, 11.4ms
# Speed: 3.6ms preprocess, 11.4ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 0, 10.3ms
# Speed: 3.0ms preprocess, 10.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-bishop, 1 black-king, 3 black-pawns, 1 black-queen, 1 white-bishop, 1 white-king, 3 white-pawns, 1 white-queen, 13.0ms
# Speed: 6.0ms preprocess, 13.0ms inference, 4.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 0, 11.3ms
# Speed: 4.1ms preprocess, 11.3ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-bishop, 1 black-king, 3 black-pawns, 1 black-queen, 1 white-bishop, 1 white-king, 3 white-pawns, 1 white-queen, 13.8ms
# Speed: 5.1ms preprocess, 13.8ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 0, 12.4ms
# Speed: 1.9ms preprocess, 12.4ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-bishop, 1 black-king, 3 black-pawns, 1 black-queen, 1 white-bishop, 1 white-king, 3 white-pawns, 1 white-queen, 12.4ms
# Speed: 4.6ms preprocess, 12.4ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 0, 8.9ms
# Speed: 2.9ms preprocess, 8.9ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-bishop, 1 black-king, 3 black-pawns, 1 black-queen, 1 white-bishop, 1 white-king, 3 white-pawns, 1 white-queen, 13.1ms
# Speed: 3.7ms preprocess, 13.1ms inference, 2.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 0, 10.7ms
# Speed: 3.6ms preprocess, 10.7ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-bishop, 1 black-king, 3 black-pawns, 1 black-queen, 1 white-bishop, 1 white-king, 3 white-pawns, 1 white-queen, 10.2ms
# Speed: 4.2ms preprocess, 10.2ms inference, 2.2ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 0, 10.4ms
# Speed: 3.1ms preprocess, 10.4ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-bishop, 1 black-king, 3 black-pawns, 1 black-queen, 1 white-bishop, 1 white-king, 3 white-pawns, 1 white-queen, 12.8ms
# Speed: 4.5ms preprocess, 12.8ms inference, 2.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 0, 11.6ms
# Speed: 3.2ms preprocess, 11.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-bishop, 1 black-king, 4 black-pawns, 1 black-queen, 1 white-bishop, 1 white-king, 3 white-pawns, 1 white-queen, 12.6ms
# Speed: 4.5ms preprocess, 12.6ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 14.1ms
# Speed: 5.5ms preprocess, 14.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-bishop, 1 black-king, 4 black-pawns, 1 black-queen, 1 white-bishop, 1 white-king, 3 white-pawns, 1 white-queen, 11.0ms
# Speed: 5.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 10.0ms
# Speed: 3.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-bishop, 1 black-king, 4 black-pawns, 1 black-queen, 1 white-bishop, 1 white-king, 3 white-pawns, 1 white-queen, 11.2ms
# Speed: 4.0ms preprocess, 11.2ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 9.7ms
# Speed: 3.0ms preprocess, 9.7ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-bishop, 1 black-king, 3 black-pawns, 1 black-queen, 1 white-bishop, 1 white-king, 3 white-pawns, 1 white-queen, 12.7ms
# Speed: 3.0ms preprocess, 12.7ms inference, 1.1ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 0, 10.0ms
# Speed: 2.1ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-bishop, 1 black-king, 4 black-pawns, 1 black-queen, 1 white-bishop, 1 white-king, 3 white-pawns, 1 white-queen, 10.3ms
# Speed: 4.2ms preprocess, 10.3ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 10.5ms
# Speed: 3.0ms preprocess, 10.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-bishop, 1 black-king, 3 black-pawns, 1 black-queen, 1 white-bishop, 1 white-king, 3 white-pawns, 1 white-queen, 9.3ms
# Speed: 3.6ms preprocess, 9.3ms inference, 2.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 0, 8.3ms
# Speed: 3.5ms preprocess, 8.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-bishop, 1 black-king,
ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 (no detections), 11.5ms
# Speed: 2.6ms preprocess, 11.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 (no detections), 12.4ms
# Speed: 2.1ms preprocess, 12.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 (no detections), 12.8ms
# Speed: 3.2ms preprocess, 12.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 (no detections), 10.8ms
# Speed: 2.9ms preprocess, 10.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 (no detections), 11.1ms
# Speed: 2.8ms preprocess, 11.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 (no detections), 10.8ms
# Speed: 3.0ms preprocess, 10.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 (no detections), 11.6ms
# Speed: 2.0ms preprocess, 11.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 (no detections), 11.2ms
# Speed: 3.0ms preprocess, 11.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 (no detections), 12.4ms
# Speed: 3.0ms preprocess, 12.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 (no detections), 11.5ms
# Speed: 2.8ms preprocess, 11.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 (no detections), 11.9ms
# Speed: 3.0ms preprocess, 11.9ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 (no detections), 11.4ms
# Speed: 3.2ms preprocess, 11.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 (no detections), 11.4ms
# Speed: 3.6ms preprocess, 11.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 (no detections), 11.2ms
# Speed: 3.0ms preprocess, 11.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 (no detections), 11.7ms
# Speed: 2.0ms preprocess, 11.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.

# %%
model_path = os.path.join('.', 'runs', 'segment', 'train_CB', 'weights', 'best.pt')
model = YOLO(model_path)

model_path1 = os.path.join('.', 'runs', 'detect', 'train_GCP', 'weights', 'best.pt')
model1 = YOLO(model_path1)

video_path = "C:/Users/Daithoulung Rongmai/Videos/Screen Recordings/Screen Recording 2024-10-25 212252.mp4" #Enter the path to the video file
video = cv2.VideoCapture(video_path)

if not video.isOpened():
    print("Error: Could not open video stream.")
    exit()

stockfish=Stockfish("StockFish/stockfish-windows-x86-64-avx2.exe")

top_moves = []

while True:
    ret, frame = video.read()
    if not ret:
        print("Error: Failed to capture frame.")
        break

    results = model.predict(frame, conf=0.5)

    warping_done = False

    for result in results:
        
        if hasattr(result, 'masks') and result.masks is not None:
            masks = result.masks.data.cpu().numpy()  

            for i in range(masks.shape[0]):
                
                mask = masks[i]
                mask_binary = (mask * 255).astype(np.uint8)
                mask_binary_resized = cv2.resize(mask_binary, (frame.shape[1], frame.shape[0]), interpolation=cv2.INTER_NEAREST)
                masked_frame = cv2.bitwise_and(frame, frame, mask=mask_binary_resized)
                contours, _ = cv2.findContours(mask_binary_resized, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
                
                if contours:
                    
                    largest_contour = max(contours, key=cv2.contourArea)
                    epsilon = 0.02 * cv2.arcLength(largest_contour, True)
                    approx_corners = cv2.approxPolyDP(largest_contour, epsilon, True)

                    if len(approx_corners) == 4:
                        
                        src_pts = np.array([pt[0] for pt in approx_corners], dtype="float32")
                        dst_pts = np.array([[0, 0], [600, 0], [600, 600], [0, 600]], dtype="float32")
                        
                        M = cv2.getPerspectiveTransform(src_pts, dst_pts)
                        warped_frame = cv2.warpPerspective(masked_frame, M, (600, 600))
                        rotated_frame = cv2.rotate(warped_frame, cv2.ROTATE_90_CLOCKWISE)
                        mirrored_frame = cv2.flip(rotated_frame, 1)

                        grid_size = 600
                        rows, cols = 8, 8
                        cell_width = grid_size // cols
                        cell_height = grid_size // rows

                        img_with_grid = mirrored_frame.copy()
                        for r in range(1, rows):
                            y = r * cell_height
                            cv2.line(img_with_grid, (0, y), (grid_size, y), (255, 0, 0), 1)
                        for c in range(1, cols):
                            x = c * cell_width
                            cv2.line(img_with_grid, (x, 0), (x, grid_size), (255, 0, 0), 1)

                        warping_done = True
                    else:
                        print("Could not find 4 corners for perspective transformation.")
                else:
                    print("No contours found for the mask.")
        else:
            print("No masks found in the results.")
    
    if not warping_done:
        for result in results:
            if hasattr(result, 'boxes') and result.boxes is not None:
                boxes = result.boxes.xyxy.cpu().numpy() 
                
                if len(boxes) > 0:
                    print("in")
                    x_min, y_min, x_max, y_max = boxes[0]
                    src_pts = np.array([[x_min, y_min], [x_max, y_min], [x_max, y_max], [x_min, y_max]], dtype="float32")
                    dst_pts = np.array([[0, 0], [600, 0], [600, 600], [0, 600]], dtype="float32")

                    M = cv2.getPerspectiveTransform(src_pts, dst_pts)
                    warped_frame = cv2.warpPerspective(frame, M, (600, 600))
                    rotated_frame = cv2.rotate(warped_frame, cv2.ROTATE_90_CLOCKWISE)
                    mirrored_frame = cv2.flip(rotated_frame, 1)

                    grid_size = 600
                    rows, cols = 8, 8
                    cell_width = grid_size // cols
                    cell_height = grid_size // rows
                    
                    img_with_grid = mirrored_frame.copy()
                    print(img_with_grid)
                    for r in range(1, rows):
                        y = r * cell_height
                        cv2.line(img_with_grid, (0, y), (grid_size, y), (255, 0, 0), 1)
                    for c in range(1, cols):
                        x = c * cell_width
                        cv2.line(img_with_grid, (x, 0), (x, grid_size), (255, 0, 0), 1)
                        
                    warping_done = True
                    break

    if not warping_done:
        frameResized = cv2.resize(frame, (600, 600))
        cv2.imshow("Chessboard", frameResized)
            
    else:
        columns = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h']
        rows_labels = ['1', '2', '3', '4', '5', '6', '7', '8']
        rows_labels.reverse()
    
        img_with_labels = img_with_grid.copy()
    
        for i in range(rows):
            for j in range(cols):
                x = i * cell_width
                y = j * cell_height
        
                label = columns[i] + rows_labels[j]
    
                text_x = x + cell_width // 2 - 15 
                text_y = y + cell_height // 2 + 15
        
                cv2.putText(img_with_labels, label, (text_x, text_y), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 0, 255), 2)
    
        res = img_with_labels.copy()
    
        piece_positions = {}
        
        results1 = model1.predict(mirrored_frame, conf=0.7)
        
        for result in results1:
            
            boxes = result.boxes.xyxy.cpu().numpy()
            classes = result.boxes.cls.cpu().numpy()
            names = result.names
            
            for box,class_id in zip(boxes,classes):
                
                x_min,y_min,x_max,y_max = box
                center_x = (x_min + x_max) / 2
                center_y = ((y_min + y_max) / 2)
                
                grid_col = int(center_x // cell_width)
                grid_row = int(center_y // cell_height)
                
                if 0 <= grid_col < cols and 0 <= grid_row < rows:
                    
                    grid_label = columns[grid_col] + rows_labels[grid_row]
                    piece_positions[grid_label] = names[int(class_id)]
                    
                    cv2.circle(res, (int(center_x), int(center_y)), 5, (255, 0, 0), -1)
                    cv2.putText(res, grid_label, (int(center_x)-10, int(center_y)-15), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 0, 255), 2)
    
        piece_map = {
            'white-rook': chess.Piece(chess.ROOK, chess.WHITE),
            'white-knight': chess.Piece(chess.KNIGHT, chess.WHITE),
            'white-bishop': chess.Piece(chess.BISHOP, chess.WHITE),
            'white-queen': chess.Piece(chess.QUEEN, chess.WHITE),
            'white-king': chess.Piece(chess.KING, chess.WHITE),
            'white-pawn': chess.Piece(chess.PAWN, chess.WHITE),
            'black-rook': chess.Piece(chess.ROOK, chess.BLACK),
            'black-knight': chess.Piece(chess.KNIGHT, chess.BLACK),
            'black-bishop': chess.Piece(chess.BISHOP, chess.BLACK),
            'black-queen': chess.Piece(chess.QUEEN, chess.BLACK),
            'black-king': chess.Piece(chess.KING, chess.BLACK),
            'black-pawn': chess.Piece(chess.PAWN, chess.BLACK),
        }
        
        def set_up_board(board, piece_positions, top_moves):
    
            try:
                for position, piece_description in piece_positions.items():
                    piece = piece_map.get(piece_description)
                    if piece:
                        square = chess.parse_square(position)
                        board.set_piece_at(square, piece)
                    else:
                        raise ValueError(f"Invalid piece description: {piece_description}")
            except Exception as e:
                print(f"Error setting up board: {e}")
                return top_moves
        
            fen_string = board.fen()

            try:
                new_board = chess.Board(fen_string)
                if not new_board.is_valid():
                    raise ValueError("Generated FEN is invalid.")
            except ValueError as e:
                print(f"Error: {e}")
                return top_moves 

            board = new_board
            
            try:
                stockfish.set_fen_position(board.fen())
                top_moves = stockfish.get_top_moves(1)
            except Exception as e:
                print(f"Stockfish error: {e}")
            
            return top_moves
            
        board = chess.Board(None)
        board.turn = chess.WHITE
        top_moves = set_up_board(board, piece_positions, top_moves)
        
        img_with_Ans = img_with_grid.copy()
        for move in top_moves:
            start_label = move['Move'][:2]  
            end_label = move['Move'][2:]
            
            for i in range(rows):
                for j in range(cols):
                    x = i * cell_width
                    y = j * cell_height
                    label = columns[i] + rows_labels[j]
                    
                    text_x = x + cell_width // 2
                    text_y = y + cell_height // 2
                    
                    if label == start_label:
                        start_x = text_x
                        start_y = text_y
                        cv2.circle(img_with_Ans, (int(text_x), int(text_y)), 5, (0, 0, 255), -1)
                        cv2.putText(img_with_Ans, label, (text_x, text_y), cv2.FONT_HERSHEY_SIMPLEX, 1, (100, 0, 255), 2)
                    
                    if label == end_label:
                        end_x = text_x
                        end_y = text_y
                        cv2.circle(img_with_Ans, (int(text_x), int(text_y)), 5, (0, 0, 255), -1)
                        cv2.putText(img_with_Ans, label, (text_x, text_y), cv2.FONT_HERSHEY_SIMPLEX, 1, (100, 0, 255), 2)
            
            cv2.arrowedLine(img_with_Ans, (start_x, start_y), (end_x, end_y), (255, 0, 0), 1, tipLength=0.1)
        
        
        cv2.imshow("Chessboard", img_with_Ans)
    
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

video.release()
cv2.destroyAllWindows()
# Out:
# 0: 800x800 1 0, 370.7ms
# Speed: 8.0ms preprocess, 370.7ms inference, 5.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 5 black-pawns, 1 black-rook, 1 white-king, 4 white-pawns, 1 white-queen, 1 white-rook, 224.8ms
# Speed: 8.5ms preprocess, 224.8ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 800x800 1 0, 321.6ms
# Speed: 7.0ms preprocess, 321.6ms inference, 3.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 5 black-pawns, 1 black-rook, 1 white-king, 4 white-pawns, 1 white-queen, 1 white-rook, 225.1ms
# Speed: 8.0ms preprocess, 225.1ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 800x800 1 0, 296.8ms
# Speed: 8.0ms preprocess, 296.8ms inference, 2.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 5 black-pawns, 1 black-rook, 1 white-king, 4 white-pawns, 1 white-queen, 1 white-rook, 218.4ms
# Speed: 8.0ms preprocess, 218.4ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 800x800 1 0, 288.6ms
# Speed: 8.0ms preprocess, 288.6ms inference, 2.1ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 5 black-pawns, 1 black-rook, 1 white-king, 4 white-pawns, 1 white-queen, 1 white-rook, 216.4ms
# Speed: 7.6ms preprocess, 216.4ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 800x800 1 0, 295.5ms
# Speed: 6.0ms preprocess, 295.5ms inference, 3.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 5 black-pawns, 1 black-rook, 1 white-king, 4 white-pawns, 1 white-queen, 1 white-rook, 111.5ms
# Speed: 4.0ms preprocess, 111.5ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 800x800 1 0, 161.2ms
# Speed: 4.5ms preprocess, 161.2ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 5 black-pawns, 1 black-rook, 1 white-king, 4 white-pawns, 1 white-queen, 1 white-rook, 123.1ms
# Speed: 4.0ms preprocess, 123.1ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 800x800 1 0, 144.5ms
# Speed: 5.0ms preprocess, 144.5ms inference, 2.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 5 black-pawns, 1 black-rook, 1 white-king, 4 white-pawns, 1 white-queen, 1 white-rook, 112.5ms
# Speed: 3.0ms preprocess, 112.5ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 800x800 1 0, 179.1ms
# Speed: 4.0ms preprocess, 179.1ms inference, 2.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 5 black-pawns, 1 black-rook, 1 white-king, 4 white-pawns, 1 white-queen, 1 white-rook, 138.5ms
# Speed: 4.0ms preprocess, 138.5ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 800x800 1 0, 185.8ms
# Speed: 4.0ms preprocess, 185.8ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 5 black-pawns, 1 black-rook, 1 white-king, 4 white-pawns, 1 white-queen, 1 white-rook, 137.5ms
# Speed: 4.0ms preprocess, 137.5ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 800x800 1 0, 198.4ms
# Speed: 4.0ms preprocess, 198.4ms inference, 2.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 5 black-pawns, 1 black-rook, 1 white-king, 4 white-pawns, 1 white-queen, 1 white-rook, 146.5ms
# Speed: 4.0ms preprocess, 146.5ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 800x800 1 0, 182.5ms
# Speed: 4.0ms preprocess, 182.5ms inference, 2.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 5 black-pawns, 1 black-rook, 1 white-king, 4 white-pawns, 1 white-queen, 1 white-rook, 149.0ms
# Speed: 4.0ms preprocess, 149.0ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 800x800 1 0, 128.1ms
# Speed: 5.0ms preprocess, 128.1ms inference, 2.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 5 black-pawns, 1 black-rook, 1 white-king, 4 white-pawns, 1 white-queen, 1 white-rook, 89.2ms
# Speed: 3.9ms preprocess, 89.2ms inference, 0.9ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 800x800 1 0, 141.9ms
# Speed: 3.9ms preprocess, 141.9ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 5 black-pawns, 1 black-rook, 1 white-king, 4 white-pawns, 1 white-queen, 1 white-rook, 92.9ms
# Speed: 3.0ms preprocess, 92.9ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 800x800 1 0, 128.3ms
# Speed: 4.1ms preprocess, 128.3ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 5 black-pawns, 1 black-rook, 1 white-king, 4 white-pawns, 1 white-queen, 1 white-rook, 91.9ms
# Speed: 4.0ms preprocess, 91.9ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 800x800 1 0, 120.8ms
# Speed: 5.0ms preprocess, 120.8ms inference, 2.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 5 black-pawns, 1 black-rook, 1 white-king, 4 white-pawns, 1 white-queen, 1 white-rook, 89.4ms
# Speed: 3.0ms preprocess, 89.4ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 800x800 1 0, 121.1ms
# Speed: 4.0ms preprocess, 121.1ms inference, 2.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 5 black-pawns, 1 black-rook, 1 white-king, 4 white-pawns, 1 white-queen, 1 white-rook, 89.2ms
# Speed: 3.9ms preprocess, 89.2ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 800x800 1 0, 125.6ms
# Speed: 5.1ms preprocess, 125.6ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 5 black-pawns, 1 black-rook, 1 white-king, 4 white-pawns, 1 white-queen, 1 white-rook, 95.1ms
# Speed: 3.1ms preprocess, 95.1ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 800x800 1 0, 124.5ms
# Speed: 3.1ms preprocess, 124.5ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 5 black-pawns, 1 black-rook, 1 white-king, 4 white-pawns, 1 white-queen, 1 white-rook, 89.7ms
# Speed: 3.0ms preprocess, 89.7ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 800x800 1 0, 119.9ms
# Speed: 4.0ms preprocess, 119.9ms inference, 1.1ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 5 black-pawns, 1 black-rook, 1 white-king, 4 white-pawns, 1 white-queen, 1 white-rook, 83.6ms
# Speed: 4.0ms preprocess, 83.6ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 800x800 1 0, 114.9ms
# Speed: 2.9ms preprocess, 114.9ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 5 black-pawns, 1 black-rook, 1 white-king, 4 white-pawns, 1 white-queen, 1 white-rook, 83.8ms
# Speed: 3.0ms preprocess, 83.8ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 800x800 1 0, 119.0ms
# Speed: 4.0ms preprocess, 119.0ms inference, 2.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 5 black-pawns, 1 black-rook, 1 white-king, 4 white-pawns, 1 white-queen, 1 white-rook, 99.6ms
# Speed: 3.7ms preprocess, 99.6ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 800x800 1 0, 126.7ms
# Speed: 4.0ms preprocess, 126.7ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 5 black-pawns, 1 black-rook, 1 white-king, 4 white-pawns, 1 white-queen, 1 white-rook, 94.7ms
# Speed: 4.0ms preprocess, 94.7ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 800x800 1 0, 129.5ms
# Speed: 4.0ms preprocess, 129.5ms inference, 1.1ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 5 black-pawns, 1 black-rook, 1 white-king, 4 white-pawns, 1 white-queen, 1 white-rook, 90.7ms
# Speed: 4.0ms preprocess, 90.7ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 800x800 1 0, 121.7ms
# Speed: 4.0ms preprocess, 121.7ms inference, 1.9ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 5 black-pawns, 1 black-rook, 1 white-king, 4 white-pawns, 1 white-queen, 1 white-rook, 90.7ms
# Speed: 4.1ms preprocess, 90.7ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 800x800 1 0, 129.3ms
# Speed: 4.0ms preprocess, 129.3ms inference, 2.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 5 black-pawns, 1 black-rook, 1 white-king, 4 white-pawns, 1 white-queen, 1 white-rook, 99.8ms
# Speed: 3.5ms preprocess, 99.8ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 800x800 1 0, 134.6ms
# Speed: 3.3ms preprocess, 134.6ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 5 black-pawns, 1 black-rook, 1 white-king, 4 white-pawns, 1 white-queen, 1 white-rook, 95.5ms
# Speed: 3.0ms preprocess, 95.5ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 800x800 1 0, 127.3ms
# Speed: 4.0ms preprocess, 127.3ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 5 black-pawns, 1 black-rook, 1 white-king, 4 white-pawns, 1 white-queen, 1 white-rook, 99.4ms
# Speed: 3.1ms preprocess, 99.4ms inference, 0.9ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 800x800 1 0, 143.4ms
# Speed: 4.0ms preprocess, 143.4ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 5 black-pawns, 1 black-rook, 1 white-king, 4 white-pawns, 1 white-queen, 1 white-rook, 106.2ms
# Speed: 4.0ms preprocess, 106.2ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 800x800 1 0, 202.5ms
# Speed: 3.0ms preprocess, 202.5ms inference, 2.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 800x800 2 black-bishops, 1 black-king, 5 black-pawns, 1 black-rook, 1 white-king, 4 white-pawns, 1 white-queen, 1 white-rook, 115.5ms
# Speed: 4.0ms preprocess, 115.5ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
