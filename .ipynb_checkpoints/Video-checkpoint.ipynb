# %%
import matplotlib.pyplot as plt
from PIL import Image
import cv2
import numpy as np
import os
from ultralytics import YOLO
import chess
from stockfish import Stockfish
import time
import threading

# %%
ch = 0

def toggle_ch():
    global ch
    while True:
        ch = 1
        time.sleep(20)

toggle_thread = threading.Thread(target=toggle_ch)
toggle_thread.start()

model_path = os.path.join('.', 'runs', 'segment', 'train_CB', 'weights', 'best.pt')
model = YOLO(model_path)

model_path1 = os.path.join('.', 'runs', 'detect', 'train_GCP', 'weights', 'best.pt')
model1 = YOLO(model_path1)

video_path = "C:/Users/Daithoulung Rongmai/Pictures/Camera Roll/WIN_20241023_20_57_10_Pro.mp4"
video = cv2.VideoCapture(video_path)

if not video.isOpened():
    print("Error: Could not open video stream.")
    exit()

stockfish=Stockfish("StockFish/stockfish-windows-x86-64-avx2.exe")
stockfish.set_depth(20)
stockfish.set_skill_level(20)
stockfish.get_parameters()
board.turn = chess.BLACK
top_moves = []

while True:
    ret, frame = video.read()
    if not ret:
        print("Error: Failed to capture frame.")
        break

    results = model.predict(frame, conf=0.5)

    warping_done = False

    for result in results:
        
        if hasattr(result, 'masks') and result.masks is not None:
            masks = result.masks.data.cpu().numpy()  

            for i in range(masks.shape[0]):
                
                mask = masks[i]
                mask_binary = (mask * 255).astype(np.uint8)
                mask_binary_resized = cv2.resize(mask_binary, (frame.shape[1], frame.shape[0]), interpolation=cv2.INTER_NEAREST)
                masked_frame = cv2.bitwise_and(frame, frame, mask=mask_binary_resized)
                contours, _ = cv2.findContours(mask_binary_resized, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
                
                if contours:
                    
                    largest_contour = max(contours, key=cv2.contourArea)
                    epsilon = 0.02 * cv2.arcLength(largest_contour, True)
                    approx_corners = cv2.approxPolyDP(largest_contour, epsilon, True)

                    if len(approx_corners) == 4:
                        
                        src_pts = np.array([pt[0] for pt in approx_corners], dtype="float32")
                        dst_pts = np.array([[0, 0], [600, 0], [600, 600], [0, 600]], dtype="float32")
                        
                        M = cv2.getPerspectiveTransform(src_pts, dst_pts)
                        warped_frame = cv2.warpPerspective(masked_frame, M, (600, 600))
                        rotated_frame = cv2.rotate(warped_frame, cv2.ROTATE_90_CLOCKWISE)
                        mirrored_frame = cv2.flip(rotated_frame, 1)

                        grid_size = 600
                        rows, cols = 8, 8
                        cell_width = grid_size // cols
                        cell_height = grid_size // rows

                        img_with_grid = mirrored_frame.copy()
                        for r in range(1, rows):
                            y = r * cell_height
                            cv2.line(img_with_grid, (0, y), (grid_size, y), (255, 0, 0), 1)
                        for c in range(1, cols):
                            x = c * cell_width
                            cv2.line(img_with_grid, (x, 0), (x, grid_size), (255, 0, 0), 1)

                        warping_done = True
                    else:
                        print("Could not find 4 corners for perspective transformation.")
                else:
                    print("No contours found for the mask.")
        else:
            print("No masks found in the results.")
    
    if not warping_done:
        for result in results:
            if hasattr(result, 'boxes') and result.boxes is not None:
                boxes = result.boxes.xyxy.cpu().numpy() 
                
                if len(boxes) > 0:
                    print("in")
                    x_min, y_min, x_max, y_max = boxes[0]
                    src_pts = np.array([[x_min, y_min], [x_max, y_min], [x_max, y_max], [x_min, y_max]], dtype="float32")
                    dst_pts = np.array([[0, 0], [600, 0], [600, 600], [0, 600]], dtype="float32")

                    M = cv2.getPerspectiveTransform(src_pts, dst_pts)
                    warped_frame = cv2.warpPerspective(frame, M, (600, 600))
                    rotated_frame = cv2.rotate(warped_frame, cv2.ROTATE_90_CLOCKWISE)
                    mirrored_frame = cv2.flip(rotated_frame, 1)

                    grid_size = 600
                    rows, cols = 8, 8
                    cell_width = grid_size // cols
                    cell_height = grid_size // rows
                    
                    img_with_grid = mirrored_frame.copy()
                    print(img_with_grid)
                    for r in range(1, rows):
                        y = r * cell_height
                        cv2.line(img_with_grid, (0, y), (grid_size, y), (255, 0, 0), 1)
                    for c in range(1, cols):
                        x = c * cell_width
                        cv2.line(img_with_grid, (x, 0), (x, grid_size), (255, 0, 0), 1)
                        
                    warping_done = True
                    break

    columns = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h']
    rows_labels = ['1', '2', '3', '4', '5', '6', '7', '8']
    rows_labels.reverse()

    img_with_labels = img_with_grid.copy()

    for i in range(rows):
        for j in range(cols):
            x = i * cell_width
            y = j * cell_height
    
            label = columns[i] + rows_labels[j]

            text_x = x + cell_width // 2 - 15 
            text_y = y + cell_height // 2 + 15
    
            cv2.putText(img_with_labels, label, (text_x, text_y), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 0, 255), 2)

    res = img_with_labels.copy()

    piece_positions = {}
    
    results1 = model1.predict(mirrored_frame, conf=0.5)
    
    for result in results1:
        
        boxes = result.boxes.xyxy.cpu().numpy()
        classes = result.boxes.cls.cpu().numpy()
        names = result.names
        
        for box,class_id in zip(boxes,classes):
            
            x_min,y_min,x_max,y_max = box
            center_x = (x_min + x_max) / 2
            center_y = ((y_min + y_max) / 2)
            
            grid_col = int(center_x // cell_width)
            grid_row = int(center_y // cell_height)
            
            if 0 <= grid_col < cols and 0 <= grid_row < rows:
                
                grid_label = columns[grid_col] + rows_labels[grid_row]
                piece_positions[grid_label] = names[int(class_id)]
                
                cv2.circle(res, (int(center_x), int(center_y)), 5, (255, 0, 0), -1)
                cv2.putText(res, grid_label, (int(center_x)-10, int(center_y)-15), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 0, 255), 2)

    piece_map = {
        'white-rook': chess.Piece(chess.ROOK, chess.WHITE),
        'white-knight': chess.Piece(chess.KNIGHT, chess.WHITE),
        'white-bishop': chess.Piece(chess.BISHOP, chess.WHITE),
        'white-queen': chess.Piece(chess.QUEEN, chess.WHITE),
        'white-king': chess.Piece(chess.KING, chess.WHITE),
        'white-pawn': chess.Piece(chess.PAWN, chess.WHITE),
        'black-rook': chess.Piece(chess.ROOK, chess.BLACK),
        'black-knight': chess.Piece(chess.KNIGHT, chess.BLACK),
        'black-bishop': chess.Piece(chess.BISHOP, chess.BLACK),
        'black-queen': chess.Piece(chess.QUEEN, chess.BLACK),
        'black-king': chess.Piece(chess.KING, chess.BLACK),
        'black-pawn': chess.Piece(chess.PAWN, chess.BLACK),
    }
    
    def set_up_board(board, piece_positions, ch, top_moves):

        try:
            for position, piece_description in piece_positions.items():
                piece = piece_map.get(piece_description)
                if piece:
                    square = chess.parse_square(position)
                    board.set_piece_at(square, piece)
                else:
                    raise ValueError(f"Invalid piece description: {piece_description}")
        except Exception as e:
            print(f"Error setting up board: {e}")
            return ch, board, top_moves
    
        fen_string = board.fen()
    
        try:
            new_board = chess.Board(fen_string)
            if not new_board.is_valid():
                raise ValueError("Generated FEN is invalid.")
        except ValueError as e:
            print(f"Error: {e}")
            return ch, board, top_moves 
    
        board = new_board
        
        if ch == 1:
            ch=0
            if (board.turn == chess.BLACK):
                board.turn = chess.WHITE 
            else:
                board.turn = chess.BLACK
            try:
                stockfish.set_fen_position(board.fen())
                top_moves = stockfish.get_top_moves(3)
            except Exception as e:
                print(f"Stockfish error: {e}")
        
        return ch, board, top_moves
        
    board = chess.Board(None)        
    ch, board, top_moves = set_up_board(board, piece_positions, ch, top_moves)
    
    img_with_Ans = res.copy()
    for i in range(rows):
        for j in range(cols):
            
            x = i * cell_width
            y = j * cell_height
            label = columns[i] + rows_labels[j]
 
            text_x = x + cell_width // 2 - 10
            text_y = y + cell_height // 2 + 10
            
            C = 0
            for move in top_moves:
                if label == (move['Move'][2:]):
                    
                    cv2.putText(img_with_Ans, label, (text_x, text_y), cv2.FONT_HERSHEY_SIMPLEX, 1, (C+100, C, 255-C), 2)
                    
                if label == (move['Move'][:2]):
                    
                    cv2.putText(img_with_Ans, label, (text_x, text_y), cv2.FONT_HERSHEY_SIMPLEX, 1, (C+100, C, 255-C), 2)
                    cv2.circle(img_with_Ans, (int(text_x), int(text_y)), 5, (0, 255, 255), -1)
                    
                C+=70
    
    cv2.imshow("Chessboard", img_with_Ans)
    
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

    time.sleep(1)

video.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 29
#      27 stockfish.set_skill_level(20)
#      28 stockfish.get_parameters()
# ---> 29 board.turn = chess.BLACK
#      30 top_moves = []
#      32 while True:
#
# NameError: name 'board' is not defined

# %%
ch = 0

def toggle_ch():
    global ch
    while True:
        ch = 1
        time.sleep(60)

toggle_thread = threading.Thread(target=toggle_ch)
toggle_thread.start()

model_path = os.path.join('.', 'runs', 'segment', 'train_CB', 'weights', 'best.pt')
model = YOLO(model_path)

model_path1 = os.path.join('.', 'runs', 'detect', 'train_GCP', 'weights', 'best.pt')
model1 = YOLO(model_path1)

video = cv2.VideoCapture(0)
address = "https://192.168.1.9:8080/video"
video.open(address)

if not video.isOpened():
    print("Error: Could not open video stream.")
    exit()

stockfish=Stockfish("StockFish/stockfish-windows-x86-64-avx2.exe")
stockfish.set_depth(20)
stockfish.set_skill_level(20)
stockfish.get_parameters()

top_moves = []

while True:
    ret, frame = video.read()
    if not ret:
        print("Error: Failed to capture frame.")
        break

    results = model.predict(frame, conf=0.5)

    warping_done = False

    for result in results:
        
        if hasattr(result, 'masks') and result.masks is not None:
            masks = result.masks.data.cpu().numpy()  

            for i in range(masks.shape[0]):
                
                mask = masks[i]
                mask_binary = (mask * 255).astype(np.uint8)
                mask_binary_resized = cv2.resize(mask_binary, (frame.shape[1], frame.shape[0]), interpolation=cv2.INTER_NEAREST)
                masked_frame = cv2.bitwise_and(frame, frame, mask=mask_binary_resized)
                contours, _ = cv2.findContours(mask_binary_resized, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
                
                if contours:
                    
                    largest_contour = max(contours, key=cv2.contourArea)
                    epsilon = 0.02 * cv2.arcLength(largest_contour, True)
                    approx_corners = cv2.approxPolyDP(largest_contour, epsilon, True)

                    if len(approx_corners) == 4:
                        
                        src_pts = np.array([pt[0] for pt in approx_corners], dtype="float32")
                        dst_pts = np.array([[0, 0], [600, 0], [600, 600], [0, 600]], dtype="float32")
                        
                        M = cv2.getPerspectiveTransform(src_pts, dst_pts)
                        warped_frame = cv2.warpPerspective(masked_frame, M, (600, 600))
                        rotated_frame = cv2.rotate(warped_frame, cv2.ROTATE_90_CLOCKWISE)
                        mirrored_frame = cv2.flip(rotated_frame, 1)

                        grid_size = 600
                        rows, cols = 8, 8
                        cell_width = grid_size // cols
                        cell_height = grid_size // rows

                        img_with_grid = mirrored_frame.copy()
                        for r in range(1, rows):
                            y = r * cell_height
                            cv2.line(img_with_grid, (0, y), (grid_size, y), (255, 0, 0), 1)
                        for c in range(1, cols):
                            x = c * cell_width
                            cv2.line(img_with_grid, (x, 0), (x, grid_size), (255, 0, 0), 1)

                        warping_done = True
                    else:
                        print("Could not find 4 corners for perspective transformation.")
                else:
                    print("No contours found for the mask.")
        else:
            print("No masks found in the results.")
    
    if not warping_done:
        for result in results:
            if hasattr(result, 'boxes') and result.boxes is not None:
                boxes = result.boxes.xyxy.cpu().numpy() 
                
                if len(boxes) > 0:
                    print("in")
                    x_min, y_min, x_max, y_max = boxes[0]
                    src_pts = np.array([[x_min, y_min], [x_max, y_min], [x_max, y_max], [x_min, y_max]], dtype="float32")
                    dst_pts = np.array([[0, 0], [600, 0], [600, 600], [0, 600]], dtype="float32")

                    M = cv2.getPerspectiveTransform(src_pts, dst_pts)
                    warped_frame = cv2.warpPerspective(frame, M, (600, 600))
                    rotated_frame = cv2.rotate(warped_frame, cv2.ROTATE_90_CLOCKWISE)
                    mirrored_frame = cv2.flip(rotated_frame, 1)

                    grid_size = 600
                    rows, cols = 8, 8
                    cell_width = grid_size // cols
                    cell_height = grid_size // rows
                    
                    img_with_grid = mirrored_frame.copy()
                    print(img_with_grid)
                    for r in range(1, rows):
                        y = r * cell_height
                        cv2.line(img_with_grid, (0, y), (grid_size, y), (255, 0, 0), 1)
                    for c in range(1, cols):
                        x = c * cell_width
                        cv2.line(img_with_grid, (x, 0), (x, grid_size), (255, 0, 0), 1)
                        
                    warping_done = True
                    break

    if not warping_done:
         cv2.imshow("Chessboard", frame)
        
    else:
        columns = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h']
        rows_labels = ['1', '2', '3', '4', '5', '6', '7', '8']
        rows_labels.reverse()
    
        img_with_labels = img_with_grid.copy()
    
        for i in range(rows):
            for j in range(cols):
                x = i * cell_width
                y = j * cell_height
        
                label = columns[i] + rows_labels[j]
    
                text_x = x + cell_width // 2 - 15 
                text_y = y + cell_height // 2 + 15
        
                cv2.putText(img_with_labels, label, (text_x, text_y), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 0, 255), 2)
    
        res = img_with_labels.copy()
    
        piece_positions = {}
        
        results1 = model1.predict(mirrored_frame, conf=0.7)
        
        for result in results1:
            
            boxes = result.boxes.xyxy.cpu().numpy()
            classes = result.boxes.cls.cpu().numpy()
            names = result.names
            
            for box,class_id in zip(boxes,classes):
                
                x_min,y_min,x_max,y_max = box
                center_x = (x_min + x_max) / 2
                center_y = ((y_min + y_max) / 2)
                
                grid_col = int(center_x // cell_width)
                grid_row = int(center_y // cell_height)
                
                if 0 <= grid_col < cols and 0 <= grid_row < rows:
                    
                    grid_label = columns[grid_col] + rows_labels[grid_row]
                    piece_positions[grid_label] = names[int(class_id)]
                    
                    cv2.circle(res, (int(center_x), int(center_y)), 5, (255, 0, 0), -1)
                    cv2.putText(res, grid_label, (int(center_x)-10, int(center_y)-15), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 0, 255), 2)
    
        piece_map = {
            'white-rook': chess.Piece(chess.ROOK, chess.WHITE),
            'white-knight': chess.Piece(chess.KNIGHT, chess.WHITE),
            'white-bishop': chess.Piece(chess.BISHOP, chess.WHITE),
            'white-queen': chess.Piece(chess.QUEEN, chess.WHITE),
            'white-king': chess.Piece(chess.KING, chess.WHITE),
            'white-pawn': chess.Piece(chess.PAWN, chess.WHITE),
            'black-rook': chess.Piece(chess.ROOK, chess.BLACK),
            'black-knight': chess.Piece(chess.KNIGHT, chess.BLACK),
            'black-bishop': chess.Piece(chess.BISHOP, chess.BLACK),
            'black-queen': chess.Piece(chess.QUEEN, chess.BLACK),
            'black-king': chess.Piece(chess.KING, chess.BLACK),
            'black-pawn': chess.Piece(chess.PAWN, chess.BLACK),
        }
        
        def set_up_board(board, piece_positions, ch, top_moves):
    
            try:
                for position, piece_description in piece_positions.items():
                    piece = piece_map.get(piece_description)
                    if piece:
                        square = chess.parse_square(position)
                        board.set_piece_at(square, piece)
                    else:
                        raise ValueError(f"Invalid piece description: {piece_description}")
            except Exception as e:
                print(f"Error setting up board: {e}")
                return ch, board, top_moves
        
            fen_string = board.fen()
            print(board)
            try:
                new_board = chess.Board(fen_string)
                if not new_board.is_valid():
                    raise ValueError("Generated FEN is invalid.")
            except ValueError as e:
                print(f"Error: {e}")
                return ch, board, top_moves 
        
            board = new_board
            
            if ch == 1:
                ch=0
                if (board.turn == chess.BLACK):
                    board.turn = chess.WHITE 
                else:
                    board.turn = chess.BLACK
                try:
                    board.turn = chess.WHITE 
                    stockfish.set_fen_position(board.fen())
                    top_moves = stockfish.get_top_moves(1)
                except Exception as e:
                    print(f"Stockfish error: {e}")
            
            return ch, board, top_moves
            
        board = chess.Board(None)
        ch, board, top_moves = set_up_board(board, piece_positions, ch, top_moves)
        
        img_with_Ans = img_with_grid.copy()
        for i in range(rows):
            for j in range(cols):
                
                x = i * cell_width
                y = j * cell_height
                label = columns[i] + rows_labels[j]
     
                text_x = x + cell_width // 2 - 10
                text_y = y + cell_height // 2 + 10
                
                C = 0
                for move in top_moves:
                    if label == (move['Move'][2:]):
                        
                        cv2.putText(img_with_Ans, label, (text_x, text_y), cv2.FONT_HERSHEY_SIMPLEX, 1, (C+100, C, 255-C), 2)
                        
                    if label == (move['Move'][:2]):
                        
                        cv2.putText(img_with_Ans, label, (text_x, text_y), cv2.FONT_HERSHEY_SIMPLEX, 1, (C+100, C, 255-C), 2)
                        cv2.circle(img_with_Ans, (int(text_x), int(text_y)), 5, (0, 255, 255), -1)
                        
                    C+=70
        
        cv2.imshow("Chessboard", img_with_Ans)
    
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

    # time.sleep(1)

video.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x800 1 0, 8.5ms
# Speed: 3.0ms preprocess, 8.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-king, 1 black-knight, 5 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 5 white-pawns, 1 white-queen, 8.0ms
# Speed: 2.5ms preprocess, 8.0ms inference, 1.5ms postprocess per image at shape (1, 3, 800, 800)
# . . . q . . Q .
# . . . . k . . .
# . . . . B . . .
# . . . p . . . .
# . . p P p n . .
# . . . . P p . .
# . . . P . . . .
# p r . . . P . P
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 8.5ms
# Speed: 3.4ms preprocess, 8.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-king, 1 black-knight, 5 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 5 white-pawns, 1 white-queen, 8.9ms
# Speed: 3.6ms preprocess, 8.9ms inference, 2.1ms postprocess per image at shape (1, 3, 800, 800)
# . . . q . . Q .
# . . . . k . . .
# . . . p B . . .
# . . . . . . . .
# . . p P p n . .
# . . . . P p . .
# . . . P . . . .
# p r . . . P . P
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 8.5ms
# Speed: 3.0ms preprocess, 8.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-king, 1 black-knight, 5 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 5 white-pawns, 1 white-queen, 9.5ms
# Speed: 5.0ms preprocess, 9.5ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
# . . . q . . Q .
# . . . . k . . .
# . . . p B . . .
# . . . . . . . .
# . . p P p n . .
# . . . . P p . .
# . . . P . . . .
# p r . . . P . P
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 9.5ms
# Speed: 3.0ms preprocess, 9.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-king, 1 black-knight, 5 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 5 white-pawns, 1 white-queen, 9.5ms
# Speed: 5.0ms preprocess, 9.5ms inference, 1.5ms postprocess per image at shape (1, 3, 800, 800)
# . . . q . . Q .
# . . . . k . . .
# . . . p B . . .
# . . . . . . . .
# . . p P p n . .
# . . . . P p . .
# . . . P . . . .
# p r . . . P . P
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 9.0ms
# Speed: 2.5ms preprocess, 9.0ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-king, 1 black-knight, 5 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 5 white-pawns, 1 white-queen, 9.5ms
# Speed: 4.5ms preprocess, 9.5ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
# . . . q . . Q .
# . . . . k . . .
# . . . p B . . .
# . . . . . . . .
# . . p P p n . .
# . . . . P p . .
# . . . P . . . .
# p r . . . P . P
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 8.3ms
# Speed: 4.0ms preprocess, 8.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-king, 1 black-knight, 5 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 5 white-pawns, 1 white-queen, 8.5ms
# Speed: 5.0ms preprocess, 8.5ms inference, 2.0ms postprocess per image at shape (1, 3, 800, 800)
# . . . q . . Q .
# . . . . k . . .
# . . . p B . . .
# . . . . . . . .
# . . p P p n . .
# . . . . P p . .
# . . . P . . . .
# p r . . . P . P
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 8.5ms
# Speed: 2.0ms preprocess, 8.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-king, 1 black-knight, 5 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 5 white-pawns, 1 white-queen, 8.5ms
# Speed: 4.0ms preprocess, 8.5ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
# . . . q . . Q .
# . . . . k . . .
# . . . p B . . .
# . . . . . . . .
# . . p P p n . .
# . . . . P p . .
# . . . P . . . .
# p r . . . P . P
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 9.5ms
# Speed: 3.3ms preprocess, 9.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-king, 1 black-knight, 5 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 5 white-pawns, 1 white-queen, 9.5ms
# Speed: 4.5ms preprocess, 9.5ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
# . . . q . . Q .
# . . . . k . . .
# . . . p B . . .
# . . . . . . . .
# . . p P p n . .
# . . . . P p . .
# . . . P . . . .
# p r . . . P . P
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 8.6ms
# Speed: 3.5ms preprocess, 8.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-king, 1 black-knight, 5 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 5 white-pawns, 1 white-queen, 8.5ms
# Speed: 4.0ms preprocess, 8.5ms inference, 2.0ms postprocess per image at shape (1, 3, 800, 800)
# . . . q . . Q .
# . . . . k . . .
# . . . p B . . .
# . . . . . . . .
# . . p P p n . .
# . . . . P p . .
# . . . P . . . .
# p r . . . P . P
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 8.5ms
# Speed: 3.5ms preprocess, 8.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-king, 1 black-knight, 5 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 5 white-pawns, 1 white-queen, 9.5ms
# Speed: 5.5ms preprocess, 9.5ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
# . . . q . . Q .
# . . . . k . . .
# . . . p B . . .
# . . . . . . . .
# . . p P p n . .
# . . . . P p . .
# . . . P . . . .
# p r . . . P . P
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 7.5ms
# Speed: 3.0ms preprocess, 7.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-king, 1 black-knight, 5 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 5 white-pawns, 1 white-queen, 8.5ms
# Speed: 4.0ms preprocess, 8.5ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
# . . . q . . Q .
# . . . . k . . .
# . . . p B . . .
# . . . . . . . .
# . . p P p n . .
# . . . . P p . .
# . . . P . . . .
# p r . . . P . P
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 8.5ms
# Speed: 3.0ms preprocess, 8.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-king, 1 black-knight, 5 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 5 white-pawns, 1 white-queen, 9.7ms
# Speed: 4.0ms preprocess, 9.7ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
# . . . q . . Q .
# . . . . k . . .
# . . . p B . . .
# . . . . . . . .
# . . p P p n . .
# . . . . P p . .
# . . . P . . . .
# p r . . . P . P
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 8.5ms
# Speed: 3.5ms preprocess, 8.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-king, 1 black-knight, 5 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 5 white-pawns, 1 white-queen, 9.5ms
# Speed: 4.0ms preprocess, 9.5ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
# . . . q . . Q .
# . . . . k . . .
# . . . p B . . .
# . . . . . n . .
# . . p P p . . .
# . . . . P p . .
# . . . P . . . .
# p r . . . P . P
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 8.2ms
# Speed: 3.3ms preprocess, 8.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-king, 1 black-knight, 5 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 5 white-pawns, 1 white-queen, 8.2ms
# Speed: 5.2ms preprocess, 8.2ms inference, 1.9ms postprocess per image at shape (1, 3, 800, 800)
# . . . q . . Q .
# . . . . k . . .
# . . . p B . . .
# . . . . . . . .
# . . p P p n . .
# . . . . P p . .
# . . . P . . . .
# p r . . . P . P
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 7.5ms
# Speed: 4.0ms preprocess, 7.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-king, 1 black-knight, 5 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 5 white-pawns, 1 white-queen, 9.5ms
# Speed: 4.5ms preprocess, 9.5ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
# . . . q . . Q .
# . . . . k . . .
# . . . p B . . .
# . . p P p n . .
# . . . . P p . .
# . . . . . . . .
# . . . P . . . .
# p r . . . P . P
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 7.5ms
# Speed: 3.0ms preprocess, 7.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 2 black-kings, 1 black-knight, 5 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 5 white-pawns, 1 white-queen, 8.5ms
# Speed: 4.1ms preprocess, 8.5ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
# . . . q . . Q .
# . . . . k . . .
# . . . p B . . .
# . . p P p n . .
# . . . . . . . .
# . . . . P p . .
# . . . P . . . .
# p r . . . P . P
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 8.0ms
# Speed: 3.5ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-king, 1 black-knight, 9 black-pawns, 2 black-queens, 1 black-rook, 1 white-bishop, 1 white-pawn, 9.5ms
# Speed: 4.5ms preprocess, 9.5ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
# . . . q . . q .
# . . . . k . . .
# . . . . B . . .
# . . . p . . . .
# . . p P p n . .
# . . . . p p . .
# . . . p . . . .
# p r . . . p . p
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 7.0ms
# Speed: 3.5ms preprocess, 7.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-king, 1 black-knight, 7 black-pawns, 2 black-queens, 1 black-rook, 1 white-bishop, 3 white-pawns, 9.5ms
# Speed: 3.0ms preprocess, 9.5ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
# . . . . q . . q
# . . . . . k . .
# . . . . . B . .
# . . . . p . . .
# . . . p P p n .
# . . . . . P . .
# . . . . p . . .
# p . r . . P . .
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 8.1ms
# Speed: 2.5ms preprocess, 8.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-king, 1 black-knight, 6 black-pawns, 2 black-queens, 1 black-rook, 1 white-bishop, 3 white-pawns, 8.5ms
# Speed: 5.0ms preprocess, 8.5ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
# . . . . q . . q
# . . . . . k . .
# . . . . . B . .
# . . . . p . . .
# . . . p P p n .
# . . . . . P . .
# . . . . P . . .
# p . r . . . . .
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 7.5ms
# Speed: 4.0ms preprocess, 7.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-king, 1 black-knight, 7 black-pawns, 2 black-queens, 1 black-rook, 1 white-bishop, 4 white-pawns, 8.5ms
# Speed: 4.0ms preprocess, 8.5ms inference, 1.7ms postprocess per image at shape (1, 3, 800, 800)
# . . . . q . . q
# . . . . . k . .
# . . . . . B . .
# . . . . p . . .
# . . . p P p n .
# . . . . . P . .
# . . . . P . . .
# p . r . . P . p
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 7.5ms
# Speed: 3.0ms preprocess, 7.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-king, 1 black-knight, 8 black-pawns, 2 black-queens, 1 black-rook, 1 white-bishop, 3 white-pawns, 8.5ms
# Speed: 5.5ms preprocess, 8.5ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
# . . . . q . q .
# . . . . . k . .
# . . . . p B . .
# . . . p P n . .
# . . . . . . . .
# . . . . . P . .
# p . . . p . . p
# . p r . . P . .
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 8.0ms
# Speed: 4.1ms preprocess, 8.0ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-king, 1 black-knight, 9 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 2 white-pawns, 9.5ms
# Speed: 3.0ms preprocess, 9.5ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
# . . . . q . . .
# . . . . . k . .
# . . . . p B . .
# . . . p P n . .
# . . . . . . . .
# . . . . . P . .
# p . . . p . . p
# . p r . . p . .
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 8.0ms
# Speed: 2.5ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-king, 1 black-knight, 7 black-pawns, 2 black-queens, 1 black-rook, 1 white-bishop, 3 white-pawns, 8.5ms
# Speed: 4.0ms preprocess, 8.5ms inference, 1.6ms postprocess per image at shape (1, 3, 800, 800)
# . . . . q . q .
# . . . . . k . .
# . . . . p B . .
# . . . . . n . .
# . . . p P p . .
# . . . . . P . .
# p . . . p . . .
# . p r . . P . .
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 8.5ms
# Speed: 4.0ms preprocess, 8.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-king, 1 black-knight, 7 black-pawns, 2 black-queens, 1 black-rook, 1 white-bishop, 2 white-pawns, 8.5ms
# Speed: 5.0ms preprocess, 8.5ms inference, 2.0ms postprocess per image at shape (1, 3, 800, 800)
# . . . . q . q .
# . . . . . k . .
# . . . . p B . .
# . . . p P n . .
# . . . . P p . .
# . . . . . . . .
# p . . . p . . .
# . p r . . . . .
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 8.5ms
# Speed: 3.0ms preprocess, 8.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-king, 1 black-knight, 6 black-pawns, 2 black-queens, 1 black-rook, 1 white-bishop, 5 white-pawns, 9.0ms
# Speed: 3.1ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
# . . . . q . q .
# . . . . . k . .
# . . . . p B . .
# . . . . . . . .
# . . . p P n . .
# . . . . P p . .
# . . . . P . . .
# p p r . . P P .
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 7.6ms
# Speed: 3.0ms preprocess, 7.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-king, 1 black-knight, 6 black-pawns, 2 black-queens, 1 black-rook, 1 white-bishop, 3 white-pawns, 7.9ms
# Speed: 6.6ms preprocess, 7.9ms inference, 2.0ms postprocess per image at shape (1, 3, 800, 800)
# . . . . q . q .
# . . . . . k . .
# . . . . p B . .
# . . . . . . . .
# . . . p P n . .
# . . . . . P . .
# . . . . P . . .
# p p r . . . . .
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 7.5ms
# Speed: 3.0ms preprocess, 7.5ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-king, 1 black-knight, 10 black-pawns, 2 black-queens, 1 white-bishop, 1 white-king, 1 white-pawn, 8.5ms
# Speed: 3.0ms preprocess, 8.5ms inference, 2.0ms postprocess per image at shape (1, 3, 800, 800)
# . . . . q . q .
# . . . . . k . .
# . . . . B . . .
# . . . . . . . .
# . . . p P n . .
# . . . . p p . .
# p p . . p p . .
# . p . . . . . K
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 7.0ms
# Speed: 2.5ms preprocess, 7.0ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-king, 1 black-knight, 6 black-pawns, 2 black-queens, 1 black-rook, 1 white-bishop, 3 white-pawns, 9.1ms
# Speed: 4.0ms preprocess, 9.1ms inference, 1.5ms postprocess per image at shape (1, 3, 800, 800)
# . . . . q . q .
# . . . . . k . .
# . . . . p B . .
# . . . p P n . .
# . . . . . p . .
# . . . . . . . .
# . . . . P . . .
# p p r . . P . .
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 7.5ms
# Speed: 3.0ms preprocess, 7.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-king, 1 black-knight, 7 black-pawns, 2 black-queens, 1 black-rook, 1 white-bishop, 3 white-pawns, 9.0ms
# Speed: 4.5ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
# . . . . q . q .
# . . . . . k . .
# . . . . p B . .
# . . . p P n . .
# . . . . . . . .
# . . . . . P . .
# . . . . P . . .
# p p r . . . . p
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 8.5ms
# Speed: 2.0ms preprocess, 8.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-king, 1 black-knight, 8 black-pawns, 2 black-queens, 1 white-bishop, 1 white-pawn, 10.5ms
# Speed: 5.5ms preprocess, 10.5ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
# . . . . q . q .
# . . . . . k . .
# . . . . . B . .
# . . . . p . . .
# . . . p P n . .
# . . . . p p . .
# . . . . p . . .
# p p . . . . . .
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 8.6ms
# Speed: 3.5ms preprocess, 8.6ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-knight, 8 black-pawns, 1 black-queen, 1 white-bishop, 1 white-pawn, 9.5ms
# Speed: 4.0ms preprocess, 9.5ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
# . . . . q . . .
# . . . . . . . .
# . . . . . B . .
# . . . . p . . .
# . . . p P n . .
# . . . . p p . .
# . . . . p . . .
# p p . . . . . .
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 8.5ms
# Speed: 3.5ms preprocess, 8.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 6 black-pawns, 1 black-queen, 9.5ms
# Speed: 4.5ms preprocess, 9.5ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
# . . . . . q . .
# . . . . . . . .
# . . . . . . . .
# . . . . p . . .
# . . . . p . . .
# . . . . . . . .
# . p . . . p . .
# p . p . . . . .
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 9.5ms
# Speed: 3.0ms preprocess, 9.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-knight, 9 black-pawns, 1 black-queen, 1 white-king, 9.5ms
# Speed: 5.0ms preprocess, 9.5ms inference, 2.0ms postprocess per image at shape (1, 3, 800, 800)
# . . . . . q . .
# . . . . . . . .
# . . . . p . . .
# . . . . p p n .
# . . . . . . p .
# . . . . p . . .
# p p . . . p . .
# . . p . . . . K
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 10.5ms
# Speed: 2.0ms preprocess, 10.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-knight, 10 black-pawns, 1 black-queen, 9.5ms
# Speed: 4.0ms preprocess, 9.5ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
# . . . . q . . .
# . . . . . . . .
# . . . . p . . .
# . . . . p p n .
# . . . . . p . .
# . . . . p . . .
# p p . . . p . .
# . . p . . . . .
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 9.0ms
# Speed: 3.0ms preprocess, 9.0ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-knight, 8 black-pawns, 1 black-queen, 1 black-rook, 9.5ms
# Speed: 5.0ms preprocess, 9.5ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
# . . . . q . . .
# . . . . . . . .
# . . . . p . . .
# . . . . p p . .
# . . . . . p . .
# . . . . p . . .
# p p . r . . . .
# . . p . . . . .
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 9.5ms
# Speed: 3.5ms preprocess, 9.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-knight, 7 black-pawns, 1 black-queen, 11.5ms
# Speed: 3.0ms preprocess, 11.5ms inference, 0.5ms postprocess per image at shape (1, 3, 800, 800)
# . . . . . q . .
# . . . . . . . .
# . . . . . . . .
# . . . . . p . .
# . . . . p p n .
# . . . . . . p .
# . . . . . . . .
# p . p p . . . .
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 9.5ms
# Speed: 2.0ms preprocess, 9.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-knight, 6 black-pawns, 1 black-queen, 1 black-rook, 10.5ms
# Speed: 4.5ms preprocess, 10.5ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
# . . . . . q . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . p p n .
# . . . . . p . .
# . . . . . . . .
# p p . r . . . .
# Error: Generated FEN is invalid.
#
# 0: 480x800 2 0s, 10.5ms
# Speed: 5.5ms preprocess, 10.5ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-king, 1 black-knight, 6 black-pawns, 2 black-queens, 1 white-bishop, 10.5ms
# Speed: 5.0ms preprocess, 10.5ms inference, 1.5ms postprocess per image at shape (1, 3, 800, 800)
# . . . q . . q .
# . . . . k . . .
# . . . p B . . .
# . . . . n . . .
# . . p p p . . .
# . . . . p . . .
# . . . . . . . .
# . . . . . . . .
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 9.5ms
# Speed: 4.0ms preprocess, 9.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-knight, 4 black-pawns, 10.0ms
# Speed: 4.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 800, 800)
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . n .
# . . . . p p . .
# . . . . . . . .
# . . . . . . . .
# p . p . . . . .
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 8.5ms
# Speed: 3.0ms preprocess, 8.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-bishop, 1 black-knight, 7 black-pawns, 1 black-queen, 10.2ms
# Speed: 4.9ms preprocess, 10.2ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
# . . . . . q . .
# . . . . . . . .
# . . . . . b . .
# . . . . . . n .
# . . . . p p . .
# . . . . . . p .
# . . . . . . . .
# p . p p . . . .
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 9.0ms
# Speed: 4.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-knight, 8 black-pawns, 1 black-queen, 1 white-bishop, 9.5ms
# Speed: 4.0ms preprocess, 9.5ms inference, 2.0ms postprocess per image at shape (1, 3, 800, 800)
# . . . . . q . .
# . . . . . . . .
# . . . . . B . .
# . . . . . . . .
# . . . . p p n .
# . . . . . . p .
# . . . . . p . .
# p . p p . . . .
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 10.5ms
# Speed: 2.5ms preprocess, 10.5ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 2 black-pawns, 1 black-queen, 10.5ms
# Speed: 4.0ms preprocess, 10.5ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
# . . . . . q . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# p . p . . . . .
# Error: Generated FEN is invalid.
#
# 0: 480x800 (no detections), 9.5ms
# Speed: 3.0ms preprocess, 9.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 1 0, 9.5ms
# Speed: 3.0ms preprocess, 9.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 3 black-pawns, 10.7ms
# Speed: 3.5ms preprocess, 10.7ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . p . . . .
# p . p . . . . .
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 9.5ms
# Speed: 3.5ms preprocess, 9.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 5 black-pawns, 10.0ms
# Speed: 4.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 800, 800)
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . p . . .
# . . . . . . . .
# . . . . . . . .
# . . . p . . . .
# p p . . . . . .
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 9.5ms
# Speed: 3.5ms preprocess, 9.5ms inference, 16.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 4 black-pawns, 9.5ms
# Speed: 4.0ms preprocess, 9.5ms inference, 2.0ms postprocess per image at shape (1, 3, 800, 800)
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . p . . . .
# p p . p . . . .
# Error: Generated FEN is invalid.
#
# 0: 480x800 (no detections), 9.5ms
# Speed: 3.5ms preprocess, 9.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 (no detections), 9.0ms
# Speed: 8.5ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 1 0, 9.0ms
# Speed: 3.5ms preprocess, 9.0ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 2 black-pawns, 10.5ms
# Speed: 4.5ms preprocess, 10.5ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# p p . . . . . .
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 10.4ms
# Speed: 3.5ms preprocess, 10.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 2 black-pawns, 10.5ms
# Speed: 3.5ms preprocess, 10.5ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# p . p . . . . .
# Error: Generated FEN is invalid.
#
# 0: 480x800 (no detections), 9.5ms
# Speed: 2.3ms preprocess, 9.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 1 0, 10.0ms
# Speed: 4.3ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-knight, 5 black-pawns, 1 black-queen, 11.5ms
# Speed: 3.5ms preprocess, 11.5ms inference, 2.0ms postprocess per image at shape (1, 3, 800, 800)
# . . . . q . . .
# . . . . . . . .
# . . . . p . . .
# . . . . . . . .
# . . . p p n . .
# . . . . . . . .
# . . . . . . . .
# p . . . . . . .
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 3 black-pawns, 10.5ms
# Speed: 3.0ms preprocess, 10.5ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . p . . .
# . . . . . . . .
# . . . . . . . .
# p p . . . . . .
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 9.5ms
# Speed: 3.1ms preprocess, 9.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 5 black-pawns, 10.5ms
# Speed: 5.5ms preprocess, 10.5ms inference, 2.0ms postprocess per image at shape (1, 3, 800, 800)
# . . . . . . . .
# . . . . . . . .
# . . . . . p . .
# . . . . p . . .
# . . . . . . . .
# . . . . . . . .
# p . . . . . . .
# . p . p . . . .
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 11.4ms
# Speed: 2.6ms preprocess, 11.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 2 black-pawns, 11.5ms
# Speed: 3.0ms preprocess, 11.5ms inference, 1.5ms postprocess per image at shape (1, 3, 800, 800)
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# p p . . . . . .
# Error: Generated FEN is invalid.
#
# 0: 480x800 (no detections), 9.5ms
# Speed: 6.0ms preprocess, 9.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 1 0, 9.2ms
# Speed: 5.5ms preprocess, 9.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 (no detections), 11.5ms
# Speed: 5.5ms preprocess, 11.5ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 9.5ms
# Speed: 4.5ms preprocess, 9.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 3 black-pawns, 10.5ms
# Speed: 3.5ms preprocess, 10.5ms inference, 2.0ms postprocess per image at shape (1, 3, 800, 800)
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# p . p p . . . .
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 10.5ms
# Speed: 2.5ms preprocess, 10.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 3 black-pawns, 10.5ms
# Speed: 3.5ms preprocess, 10.5ms inference, 2.0ms postprocess per image at shape (1, 3, 800, 800)
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# p . p p . . . .
# Error: Generated FEN is invalid.
#
# 0: 480x800 (no detections), 10.3ms
# Speed: 3.0ms preprocess, 10.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 (no detections), 10.5ms
# Speed: 3.5ms preprocess, 10.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 (no detections), 10.5ms
# Speed: 3.0ms preprocess, 10.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 1 0, 10.5ms
# Speed: 3.5ms preprocess, 10.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 2 black-pawns, 11.1ms
# Speed: 5.5ms preprocess, 11.1ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# p p . . . . . .
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 9.5ms
# Speed: 4.0ms preprocess, 9.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 2 black-pawns, 10.5ms
# Speed: 5.5ms preprocess, 10.5ms inference, 4.0ms postprocess per image at shape (1, 3, 800, 800)
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# p . p . . . . .
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 11.5ms
# Speed: 4.5ms preprocess, 11.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 2 black-pawns, 11.5ms
# Speed: 4.5ms preprocess, 11.5ms inference, 2.0ms postprocess per image at shape (1, 3, 800, 800)
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# p p . . . . . .
# Error: Generated FEN is invalid.
#
# 0: 480x800 (no detections), 10.5ms
# Speed: 2.5ms preprocess, 10.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 1 0, 10.5ms
# Speed: 3.5ms preprocess, 10.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 2 black-pawns, 11.5ms
# Speed: 5.0ms preprocess, 11.5ms inference, 0.5ms postprocess per image at shape (1, 3, 800, 800)
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# p p . . . . . .
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 10.5ms
# Speed: 3.5ms preprocess, 10.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
# Could not find 4 corners for perspective transformation.
# in
# [[[141 177 158]
#   [131 176 148]
#   [128 176 148]
#   ...
#   [ 77  76  78]
#   [ 75  74  76]
#   [ 71  70  72]]
#
#  [[146 179 158]
#   [133 176 149]
#   [131 176 149]
#   ...
#   [ 77  76  78]
#   [ 78  77  79]
#   [ 80  79  81]]
#
#  [[132 178 158]
#   [127 179 153]
#   [126 178 152]
#   ...
#   [ 56  66  63]
#   [ 56  66  63]
#   [ 54  64  61]]
#
#  ...
#
#  [[172 178 185]
#   [175 181 191]
#   [165 172 183]
#   ...
#   [105 112 127]
#   [133 140 155]
#   [141 148 163]]
#
#  [[170 176 183]
#   [173 179 189]
#   [165 172 183]
#   ...
#   [ 80  87 102]
#   [104 111 126]
#   [135 142 157]]
#
#  [[170 176 183]
#   [173 179 189]
#   [165 172 183]
#   ...
#   [ 81  88 103]
#   [ 74  81  96]
#   [ 88  95 110]]]
#
# 0: 800x800 (no detections), 11.5ms
# Speed: 4.0ms preprocess, 11.5ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 10.5ms
# Speed: 2.5ms preprocess, 10.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 2 black-pawns, 11.5ms
# Speed: 4.5ms preprocess, 11.5ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# p p . . . . . .
# Error: Generated FEN is invalid.
#
# 0: 480x800 (no detections), 11.0ms
# Speed: 3.0ms preprocess, 11.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 1 0, 10.5ms
# Speed: 3.2ms preprocess, 10.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-pawn, 13.0ms
# Speed: 6.0ms preprocess, 13.0ms inference, 2.0ms postprocess per image at shape (1, 3, 800, 800)
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# p . . . . . . .
# . . . . . . . .
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 9.8ms
# Speed: 4.0ms preprocess, 9.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 4 black-pawns, 11.5ms
# Speed: 4.0ms preprocess, 11.5ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# p . p p p . . .
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 10.5ms
# Speed: 3.0ms preprocess, 10.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 4 black-pawns, 12.2ms
# Speed: 3.5ms preprocess, 12.2ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# p . p p p . . .
# Error: Generated FEN is invalid.
#
# 0: 480x800 (no detections), 10.5ms
# Speed: 3.0ms preprocess, 10.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 (no detections), 11.1ms
# Speed: 3.0ms preprocess, 11.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 (no detections), 10.2ms
# Speed: 3.0ms preprocess, 10.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 1 0, 10.5ms
# Speed: 2.5ms preprocess, 10.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 2 black-pawns, 11.5ms
# Speed: 4.5ms preprocess, 11.5ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# p . . . . . . .
# . p . . . . . .
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 11.5ms
# Speed: 3.5ms preprocess, 11.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 2 black-pawns, 1 white-king, 11.5ms
# Speed: 6.0ms preprocess, 11.5ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# p . . . . . . .
# . p . . . . . K
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 13.3ms
# Speed: 3.1ms preprocess, 13.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 2 black-pawns, 15.1ms
# Speed: 5.0ms preprocess, 15.1ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# p . . . . . . .
# . . p . . . . .
# Error: Generated FEN is invalid.
#
# 0: 480x800 (no detections), 14.5ms
# Speed: 3.0ms preprocess, 14.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 (no detections), 12.5ms
# Speed: 3.5ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 (no detections), 13.0ms
# Speed: 3.0ms preprocess, 13.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 1 0, 14.5ms
# Speed: 3.0ms preprocess, 14.5ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 2 black-pawns, 1 black-rook, 15.0ms
# Speed: 5.0ms preprocess, 15.0ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
# . . . . . r . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# p . . . . . . .
# . . p . . . . .
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 13.5ms
# Speed: 3.5ms preprocess, 13.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
# Could not find 4 corners for perspective transformation.
# in
# [[[207 215 226]
#   [207 215 226]
#   [207 215 226]
#   ...
#   [ 26  28  20]
#   [ 26  28  20]
#   [ 26  28  20]]
#
#  [[207 215 226]
#   [207 215 226]
#   [207 215 226]
#   ...
#   [ 27  29  21]
#   [ 27  29  21]
#   [ 27  29  21]]
#
#  [[207 215 226]
#   [207 215 226]
#   [207 215 226]
#   ...
#   [ 28  30  22]
#   [ 28  30  22]
#   [ 28  30  22]]
#
#  ...
#
#  [[172 173 181]
#   [174 175 183]
#   [170 171 179]
#   ...
#   [ 73  72  80]
#   [ 73  72  79]
#   [ 74  73  77]]
#
#  [[172 173 181]
#   [174 175 183]
#   [170 171 179]
#   ...
#   [ 73  72  80]
#   [ 71  70  77]
#   [ 73  72  75]]
#
#  [[172 173 181]
#   [174 175 183]
#   [170 171 179]
#   ...
#   [ 72  71  79]
#   [ 71  70  77]
#   [ 72  71  75]]]
#
# 0: 800x800 1 black-pawn, 13.5ms
# Speed: 5.5ms preprocess, 13.5ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . p . . . .
# . . . . . . . .
# . . . . . . . .
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 13.5ms
# Speed: 2.5ms preprocess, 13.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-pawn, 14.1ms
# Speed: 2.9ms preprocess, 14.1ms inference, 2.0ms postprocess per image at shape (1, 3, 800, 800)
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# p . . . . . . .
# . . . . . . . .
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 12.5ms
# Speed: 4.0ms preprocess, 12.5ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 4 black-pawns, 14.1ms
# Speed: 5.0ms preprocess, 14.1ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# p . . . . . . .
# . . p p p . . .
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 12.5ms
# Speed: 3.0ms preprocess, 12.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 4 black-pawns, 14.6ms
# Speed: 4.5ms preprocess, 14.6ms inference, 2.2ms postprocess per image at shape (1, 3, 800, 800)
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# p . p p p . . .
# . . . . . . . .
# Error: Generated FEN is invalid.
#
# 0: 480x800 (no detections), 13.4ms
# Speed: 3.1ms preprocess, 13.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 (no detections), 13.2ms
# Speed: 4.0ms preprocess, 13.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 (no detections), 12.7ms
# Speed: 2.7ms preprocess, 12.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 1 0, 13.4ms
# Speed: 4.6ms preprocess, 13.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 2 black-pawns, 12.3ms
# Speed: 4.0ms preprocess, 12.3ms inference, 2.5ms postprocess per image at shape (1, 3, 800, 800)
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# p p . . . . . .
# . . . . . . . .
# . . . . . . . .
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 13.1ms
# Speed: 3.0ms preprocess, 13.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 3 black-pawns, 13.6ms
# Speed: 4.5ms preprocess, 13.6ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# p p p . . . . .
# . . . . . . . .
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 12.7ms
# Speed: 4.3ms preprocess, 12.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 2 black-pawns, 13.8ms
# Speed: 2.7ms preprocess, 13.8ms inference, 2.0ms postprocess per image at shape (1, 3, 800, 800)
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# p p . . . . . .
# . . . . . . . .
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 13.5ms
# Speed: 2.5ms preprocess, 13.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-king, 1 black-knight, 5 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 5 white-pawns, 1 white-queen, 14.0ms
# Speed: 6.0ms preprocess, 14.0ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
# . . . q . . Q .
# . . . . k . . .
# . . . p B . . .
# . . p P p n . .
# . . . . P p . .
# . . . P . . . .
# p r . . . P . P
# . . . . . . . K
#
# 0: 480x800 1 0, 13.5ms
# Speed: 3.5ms preprocess, 13.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-king, 1 black-knight, 5 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 5 white-pawns, 1 white-queen, 13.5ms
# Speed: 4.5ms preprocess, 13.5ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
# . . . q . . Q .
# . . . . k . . .
# . . . p B . . .
# . . p P p n . .
# . . . . P p . .
# . . . P . . . .
# p r . . . P . P
# . . . . . . . K
#
# 0: 480x800 1 0, 12.5ms
# Speed: 4.4ms preprocess, 12.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 2 black-kings, 1 black-knight, 5 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 5 white-pawns, 1 white-queen, 15.1ms
# Speed: 4.0ms preprocess, 15.1ms inference, 2.0ms postprocess per image at shape (1, 3, 800, 800)
# . . . q . . Q .
# . . . . k . . .
# . . . p B . . .
# . . p P p n . .
# . . . . P p . .
# . . . P . . . .
# p r . . . P . P
# . . . . . . . k
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 12.5ms
# Speed: 2.5ms preprocess, 12.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 2 black-kings, 1 black-knight, 5 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 5 white-pawns, 1 white-queen, 15.3ms
# Speed: 3.0ms preprocess, 15.3ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
# . . . q . . Q .
# . . . . k . . .
# . . . p B . . .
# . . p P p n . .
# . . . . P p . .
# . . . P . . . .
# p r . . . P . P
# . . . . . . . k
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 12.5ms
# Speed: 2.5ms preprocess, 12.5ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 2 black-kings, 1 black-knight, 5 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 5 white-pawns, 1 white-queen, 13.3ms
# Speed: 4.0ms preprocess, 13.3ms inference, 2.0ms postprocess per image at shape (1, 3, 800, 800)
# . . . q . . Q .
# . . . . k . . .
# . . . p B . . .
# . . p P p n . .
# . . . . P p . .
# . . . P . . . .
# . r . . . P . P
# p . . . . . . k
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 13.6ms
# Speed: 3.0ms preprocess, 13.6ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 2 black-kings, 1 black-knight, 5 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 5 white-pawns, 1 white-queen, 15.0ms
# Speed: 4.0ms preprocess, 15.0ms inference, 2.0ms postprocess per image at shape (1, 3, 800, 800)
# . . . q . . Q .
# . . . . k . . .
# . . . p B . . .
# . . p P p n . .
# . . . . P p . .
# . . . P . . . .
# . r . . . P . P
# p . . . . . . k
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 12.5ms
# Speed: 2.0ms preprocess, 12.5ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 2 black-kings, 1 black-knight, 5 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 5 white-pawns, 1 white-queen, 13.5ms
# Speed: 4.5ms preprocess, 13.5ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
# . . . q . . Q .
# . . . . k . . .
# . . . p B . . .
# . . p P p n . .
# . . . . P p . .
# . . . P . . . .
# . . . . . P . P
# p r . . . . . k
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 12.5ms
# Speed: 3.0ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 2 black-kings, 1 black-knight, 5 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 5 white-pawns, 1 white-queen, 13.5ms
# Speed: 4.5ms preprocess, 13.5ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
# . . . q . . Q .
# . . . . k . . .
# . . . p B . . .
# . . p P p n . .
# . . . . P p . .
# . . . P . . . .
# . . . . . P . P
# p r . . . . . k
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 12.5ms
# Speed: 3.0ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 2 black-kings, 1 black-knight, 5 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 5 white-pawns, 1 white-queen, 16.0ms
# Speed: 5.0ms preprocess, 16.0ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
# . . . q . . Q .
# . . . . k . . .
# . . . p B . . .
# . . p P p n . .
# . . . . P p . .
# . . . P . . . .
# . . . . . P . P
# p r . . . . . k
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 14.5ms
# Speed: 2.5ms preprocess, 14.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 2 black-kings, 1 black-knight, 5 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 5 white-pawns, 1 white-queen, 15.0ms
# Speed: 5.0ms preprocess, 15.0ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
# . . . q . . Q .
# . . . . k . . .
# . . . p B . . .
# . . p P p n . .
# . . . . P p . .
# . . . P . . . .
# . . . . . P . P
# p r . . . . . k
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 14.0ms
# Speed: 2.2ms preprocess, 14.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 2 black-kings, 1 black-knight, 5 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 5 white-pawns, 1 white-queen, 15.0ms
# Speed: 5.0ms preprocess, 15.0ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
# . . . q . . Q .
# . . . . k . . .
# . . . p B . . .
# . . p P p n . .
# . . . . P p . .
# . . . P . . . .
# . . . . . P . P
# p r . . . . . k
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 13.8ms
# Speed: 3.0ms preprocess, 13.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 2 black-kings, 1 black-knight, 5 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 5 white-pawns, 1 white-queen, 16.5ms
# Speed: 4.0ms preprocess, 16.5ms inference, 1.5ms postprocess per image at shape (1, 3, 800, 800)
# . . . q . . Q .
# . . . . k . . .
# . . . p B . . .
# . . p P p n . .
# . . . . P p . .
# . . . P . . . .
# . . . . . P . P
# p r . . . . . k
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 13.9ms
# Speed: 3.0ms preprocess, 13.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 2 black-kings, 1 black-knight, 5 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 5 white-pawns, 1 white-queen, 15.5ms
# Speed: 4.5ms preprocess, 15.5ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
# . . . q . . Q .
# . . . . k . . .
# . . . p B . . .
# . . p P p n . .
# . . . . P p . .
# . . . P . . . .
# . . . . . P . P
# p r . . . . . k
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 14.0ms
# Speed: 4.0ms preprocess, 14.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 2 black-kings, 1 black-knight, 5 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 5 white-pawns, 1 white-queen, 15.5ms
# Speed: 7.4ms preprocess, 15.5ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
# . . . q . . Q .
# . . . . k . . .
# . . . p B . . .
# . . p P p n . .
# . . . . P p . .
# . . . P . . . .
# . . . . . P . P
# p r . . . . . k
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 16.0ms
# Speed: 3.0ms preprocess, 16.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 2 black-kings, 1 black-knight, 5 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 5 white-pawns, 1 white-queen, 15.0ms
# Speed: 4.0ms preprocess, 15.0ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
# . . . q . . Q .
# . . . . k . . .
# . . . p B . . .
# . . p P p n . .
# . . . . P p . .
# . . . P . . . .
# . . . . . P . P
# p r . . . . . k
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 14.5ms
# Speed: 3.0ms preprocess, 14.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 2 black-kings, 1 black-knight, 5 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 5 white-pawns, 1 white-queen, 15.5ms
# Speed: 3.3ms preprocess, 15.5ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
# . . . q . . Q .
# . . . . k . . .
# . . . p B . . .
# . . p P p n . .
# . . . . P p . .
# . . . P . . . .
# . . . . . P . P
# p r . . . . . k
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 13.5ms
# Speed: 3.0ms preprocess, 13.5ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-king, 1 black-knight, 5 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 1 white-king, 5 white-pawns, 1 white-queen, 14.5ms
# Speed: 3.5ms preprocess, 14.5ms inference, 2.0ms postprocess per image at shape (1, 3, 800, 800)
# . . . q . . Q .
# . . . . k . . .
# . . . p B . . .
# . . . . . n . .
# . . p P p . . .
# . . . . P p . .
# . . . P . . . .
# p r . . . P . K
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 14.3ms
# Speed: 2.2ms preprocess, 14.3ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-king, 1 black-knight, 5 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 5 white-pawns, 1 white-queen, 14.5ms
# Speed: 4.5ms preprocess, 14.5ms inference, 2.0ms postprocess per image at shape (1, 3, 800, 800)
# . . . q . . Q .
# . . . . k . . .
# . . . p B . . .
# . . . . . n . .
# . . p P p . . .
# . . . . P p . .
# . . . P . . . .
# p r . . . P . P
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 14.5ms
# Speed: 2.5ms preprocess, 14.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 1 black-king, 1 black-knight, 5 black-pawns, 1 black-queen, 1 black-rook, 1 white-bishop, 5 white-pawns, 1 white-queen, 16.0ms
# ...
# . . . . n . . .
# . . . . . . . .
# . . . . . . . .
# . . p . p n . .
# . . . . . p . .
# . . . . . . . .
# . . . . . p . .
# . . . . . . . .
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 11.3ms
# Speed: 3.5ms preprocess, 11.3ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 2 black-knights, 13.1ms
# Speed: 5.0ms preprocess, 13.1ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
# . . . . n . . .
# . . . . . . . .
# . . . . . n . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 11.4ms
# Speed: 3.0ms preprocess, 11.4ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 800x800 (no detections), 11.7ms
# Speed: 4.0ms preprocess, 11.7ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 800)
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# Error: Generated FEN is invalid.
#
# 0: 480x800 1 0, 11.5ms
# Speed: 2.5ms preprocess, 11.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
# Could not find 4 corners for perspective transformation.
# in
# [[[200 204 216]
#   [200 204 216]
#   [200 204 216]
#   ...
#   [ 35  32  29]
#   [ 64  61  58]
#   [ 84  81  78]]
#
#  [[200 204 216]
#   [200 204 216]
#   [200 204 216]
#   ...
#   [ 62  59  56]
#   [ 86  83  80]
#   [ 88  85  82]]
#
#  [[200 204 216]
#   [200 204 216]
#   [200 204 216]
#   ...
#   [ 89  86  83]
#   [ 85  82  79]
#   [ 79  76  73]]
#
#  ...
#
#  [[ 55  85  73]
#   [ 55  85  73]
#   [ 55  85  73]
#   ...
#   [111 121 127]
#   [112 122 128]
#   [113 123 129]]
#
#  [[ 54  84  72]
#   [ 54  84  72]
#   [ 54  84  72]
#   ...
#   [111 121 127]
#   [112 122 128]
#   [113 123 129]]
#
#  [[ 53  83  71]
#   [ 53  83  71]
#   [ 53  83  71]
#   ...
#   [111 121 127]
#   [112 122 128]
#   [113 123 129]]]
#
# 0: 800x800 (no detections), 12.5ms
# Speed: 5.7ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# Error: Generated FEN is invalid.
#
# 0: 480x800 (no detections), 12.1ms
# Speed: 4.6ms preprocess, 12.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 (no detections), 11.5ms
# Speed: 3.5ms preprocess, 11.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 (no detections), 11.3ms
# Speed: 2.9ms preprocess, 11.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 (no detections), 11.4ms
# Speed: 1.7ms preprocess, 11.4ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 (no detections), 11.7ms
# Speed: 2.7ms preprocess, 11.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 (no detections), 10.7ms
# Speed: 4.0ms preprocess, 10.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 (no detections), 11.3ms
# Speed: 4.0ms preprocess, 11.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 (no detections), 11.8ms
# Speed: 2.0ms preprocess, 11.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 (no detections), 12.4ms
# Speed: 2.9ms preprocess, 12.4ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 (no detections), 11.6ms
# Speed: 4.5ms preprocess, 11.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 (no detections), 11.7ms
# Speed: 3.0ms preprocess, 11.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 (no detections), 12.7ms
# Speed: 3.1ms preprocess, 12.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 (no detections), 11.1ms
# Speed: 4.0ms preprocess, 11.1ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 (no detections), 10.7ms
# Speed: 3.0ms preprocess, 10.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 (no detections), 10.7ms
# Speed: 2.9ms preprocess, 10.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 (no detections), 11.5ms
# Speed: 3.6ms preprocess, 11.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 (no detections), 11.6ms
# Speed: 3.0ms preprocess, 11.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 (no detections), 11.5ms
# Speed: 3.5ms preprocess, 11.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 (no detections), 11.7ms
# Speed: 2.1ms preprocess, 11.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 (no detections), 11.8ms
# Speed: 2.9ms preprocess, 11.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 (no detections), 11.5ms
# Speed: 3.0ms preprocess, 11.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 (no detections), 11.3ms
# Speed: 4.0ms preprocess, 11.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 (no detections), 11.5ms
# Speed: 2.0ms preprocess, 11.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 (no detections), 13.6ms
# Speed: 2.0ms preprocess, 13.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 (no detections), 11.5ms
# Speed: 2.5ms preprocess, 11.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 (no detections), 11.5ms
# Speed: 3.5ms preprocess, 11.5ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 (no detections), 11.5ms
# Speed: 4.2ms preprocess, 11.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 (no detections), 12.1ms
# Speed: 3.0ms preprocess, 12.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 (no detections), 11.7ms
# Speed: 3.7ms preprocess, 11.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 (no detections), 11.7ms
# Speed: 3.5ms preprocess, 11.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 (no detections), 12.5ms
# Speed: 3.0ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 (no detections), 12.1ms
# Speed: 3.0ms preprocess, 12.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 (no detections), 13.0ms
# Speed: 3.0ms preprocess, 13.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 (no detections), 11.5ms
# Speed: 2.0ms preprocess, 11.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 (no detections), 10.8ms
# Speed: 4.0ms preprocess, 10.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 (no detections), 11.6ms
# Speed: 3.6ms preprocess, 11.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 (no detections), 11.5ms
# Speed: 4.5ms preprocess, 11.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 (no detections), 12.5ms
# Speed: 4.5ms preprocess, 12.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 (no detections), 11.6ms
# Speed: 3.1ms preprocess, 11.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 (no detections), 11.5ms
# Speed: 3.0ms preprocess, 11.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 (no detections), 11.3ms
# Speed: 2.0ms preprocess, 11.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 (no detections), 10.7ms
# Speed: 3.6ms preprocess, 10.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 (no detections), 12.7ms
# Speed: 4.7ms preprocess, 12.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 (no detections), 12.5ms
# Speed: 3.5ms preprocess, 12.5ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 (no detections), 12.5ms
# Speed: 2.0ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 (no detections), 12.5ms
# Speed: 2.0ms preprocess, 12.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 (no detections), 12.6ms
# Speed: 4.5ms preprocess, 12.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 (no detections), 12.5ms
# Speed: 4.5ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 (no detections), 12.3ms
# Speed: 4.0ms preprocess, 12.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 (no detections), 11.8ms
# Speed: 4.0ms preprocess, 11.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 (no detections), 11.7ms
# Speed: 3.0ms preprocess, 11.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 (no detections), 11.5ms
# Speed: 3.0ms preprocess, 11.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 (no detections), 12.1ms
# Speed: 3.0ms preprocess, 12.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 (no detections), 11.8ms
# Speed: 4.5ms preprocess, 11.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 (no detections), 13.0ms
# Speed: 2.9ms preprocess, 13.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 (no detections), 11.6ms
# Speed: 3.0ms preprocess, 11.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 (no detections), 12.5ms
# Speed: 7.2ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 (no detections), 11.7ms
# Speed: 4.1ms preprocess, 11.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 (no detections), 12.7ms
# Speed: 4.0ms preprocess, 12.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 (no detections), 11.9ms
# Speed: 2.0ms preprocess, 11.9ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 (no detections), 11.6ms
# Speed: 3.0ms preprocess, 11.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 (no detections), 12.2ms
# Speed: 3.0ms preprocess, 12.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 (no detections), 11.8ms
# Speed: 3.6ms preprocess, 11.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 (no detections), 11.7ms
# Speed: 3.0ms preprocess, 11.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 (no detections), 12.1ms
# Speed: 3.7ms preprocess, 12.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 (no detections), 12.4ms
# Speed: 5.0ms preprocess, 12.4ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 (no detections), 11.7ms
# Speed: 4.0ms preprocess, 11.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 (no detections), 11.7ms
# Speed: 3.6ms preprocess, 11.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 (no detections), 11.8ms
# Speed: 3.7ms preprocess, 11.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 (no detections), 13.0ms
# Speed: 2.0ms preprocess, 13.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 (no detections), 11.7ms
# Speed: 2.8ms preprocess, 11.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 (no detections), 11.7ms
# Speed: 2.0ms preprocess, 11.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 (no detections), 12.4ms
# Speed: 3.1ms preprocess, 12.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 (no detections), 13.2ms
# Speed: 5.0ms preprocess, 13.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 (no detections), 11.2ms
# Speed: 3.9ms preprocess, 11.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 (no detections), 12.6ms
# Speed: 4.0ms preprocess, 12.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 (no detections), 11.7ms
# Speed: 2.1ms preprocess, 11.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 (no detections), 11.4ms
# Speed: 3.0ms preprocess, 11.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 (no detections), 10.5ms
# Speed: 3.1ms preprocess, 10.5ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 (no detections), 12.1ms
# Speed: 3.0ms preprocess, 12.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 (no detections), 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 (no detections), 11.7ms
# Speed: 4.4ms preprocess, 11.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 (no detections), 12.7ms
# Speed: 2.0ms preprocess, 12.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
#
# 0: 480x800 (no detections), 11.4ms
# Speed: 2.0ms preprocess, 11.4ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 800)
# No masks found in the results.
# Error: Failed to capture frame.
